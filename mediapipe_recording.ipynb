# %%
#######################################################################################################################################################################
# Angle Calculation using Mediapipe Pose Visualization #
#######################################################################################################################################################################
import cv2
import mediapipe as mp
import numpy as np

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Function to calculate the angle between three points
def calculate_angle(a, b, c):
    """Calculate angle between three 2D points using arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))

    return np.degrees(angle)

# Open webcam
cap = cv2.VideoCapture("asitwas.webm")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Define key joints (Using Mediapipe landmark indices)
        joint_ids = {
            "nose": 0,
            "left_shoulder": 11, "right_shoulder": 12,
            "left_elbow": 13, "right_elbow": 14,
            "left_wrist": 15, "right_wrist": 16,
            "left_waist": 23, "right_waist": 24  # Waist is hip landmarks
        }

        # Extract 2D coordinates
        joints = {}
        for name, idx in joint_ids.items():
            if landmarks[idx].visibility > 0.5:  # Ensure the joint is visible
                joints[name] = (int(landmarks[idx].x * frame.shape[1]), 
                                int(landmarks[idx].y * frame.shape[0]))

        # Compute mid_shoulder (midpoint of left and right shoulder)
        if all(k in joints for k in ["left_shoulder", "right_shoulder"]):
            joints["mid_shoulder"] = ((joints["left_shoulder"][0] + joints["right_shoulder"][0]) // 2,
                                      (joints["left_shoulder"][1] + joints["right_shoulder"][1]) // 2)

        # Compute angles only if required points exist
        angles = {}
        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["Left Elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["right_shoulder", "right_elbow", "right_wrist"]):
            angles["Right Elbow"] = calculate_angle(joints["right_shoulder"], joints["right_elbow"], joints["right_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_waist"]):
            angles["Left Arm Lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_waist"])
        if all(k in joints for k in ["right_elbow", "right_shoulder", "right_waist"]):
            angles["Right Arm Lift"] = calculate_angle(joints["right_elbow"], joints["right_shoulder"], joints["right_waist"])
        if all(k in joints for k in ["nose", "mid_shoulder", "left_shoulder"]):
            angles["Neck Angle"] = calculate_angle(joints["nose"], joints["mid_shoulder"], joints["left_shoulder"])

        # Draw key points and lines
        for (p1, p2, p3, label, text_pos) in [
            ("left_shoulder", "left_elbow", "left_wrist", "Left Elbow", "left_elbow"),
            ("right_shoulder", "right_elbow", "right_wrist", "Right Elbow", "right_elbow"),
            ("left_elbow", "left_shoulder", "left_waist", "Left Arm Lift", "left_shoulder"),
            ("right_elbow", "right_shoulder", "right_waist", "Right Arm Lift", "right_shoulder")
        ]:
            if all(k in joints for k in [p1, p2, p3]):
                # Draw lines
                cv2.line(frame, joints[p1], joints[p2], (0, 255, 0), 3)
                cv2.line(frame, joints[p2], joints[p3], (0, 255, 0), 3)

                # Draw key points
                cv2.circle(frame, joints[p1], 6, (0, 0, 255), -1)
                cv2.circle(frame, joints[p2], 6, (255, 0, 0), -1)
                cv2.circle(frame, joints[p3], 6, (0, 255, 255), -1)

                # Display angle
                if label in angles:
                    angle_text = f"{label}: {int(angles[label])}"
                    cv2.putText(frame, angle_text, (joints[text_pos][0] + 20, joints[text_pos][1]), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

        # Draw neck angle separately
        if all(k in joints for k in ["nose", "mid_shoulder", "left_shoulder"]) and "Neck Angle" in angles:
            cv2.line(frame, joints["nose"], joints["mid_shoulder"], (0, 255, 0), 3)
            cv2.line(frame, joints["mid_shoulder"], joints["left_shoulder"], (0, 255, 0), 3)

            cv2.circle(frame, joints["nose"], 6, (0, 0, 255), -1)
            cv2.circle(frame, joints["mid_shoulder"], 6, (255, 0, 0), -1)
            cv2.circle(frame, joints["left_shoulder"], 6, (0, 255, 255), -1)

            # Display neck angle
            angle_text = f"Neck Angle: {int(angles['Neck Angle'])}"
            cv2.putText(frame, angle_text, (joints["nose"][0] + 20, joints["nose"][1]), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # Show the frame
    cv2.imshow("Pose Angle Visualization", frame)

    # Exit if 'q' is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\kshit\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
#######################################################################################################################################################################
# Move Detection, Recording and Preprocessing #
#######################################################################################################################################################################

import cv2
import mediapipe as mp
import json
import numpy as np
import time
import os

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

# Extract moves
moves = timeline_data["moves"]

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Directory to save processed reference data
output_dir = "reference_moves"
os.makedirs(output_dir, exist_ok=True)

def calculate_angle(a, b, c):
    """Calculate angle between three 3D points using the arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))
    
    return np.degrees(angle)

def process_frame(image):
    """Extract pose landmarks from a frame and compute angles."""
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)
    
    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark
        
        # Extract key joint coordinates (normalized values)
        joint_ids = {
            "nose": 0,
            "left_shoulder": 11, "right_shoulder": 12,
            "left_elbow": 13, "right_elbow": 14,
            "left_wrist": 15, "right_wrist": 16,
            "left_hip": 23, "right_hip": 24
        }
        
        joints = {name: (landmarks[idx].x, landmarks[idx].y, landmarks[idx].z) for name, idx in joint_ids.items()}

        # Compute mid-shoulder point
        if "left_shoulder" in joints and "right_shoulder" in joints:
            mid_shoulder = (
                (joints["left_shoulder"][0] + joints["right_shoulder"][0]) / 2,
                (joints["left_shoulder"][1] + joints["right_shoulder"][1]) / 2,
                (joints["left_shoulder"][2] + joints["right_shoulder"][2]) / 2
            )
        else:
            mid_shoulder = None

        # Compute angles
        angles = {}

        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["left_elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["right_shoulder", "right_elbow", "right_wrist"]):
            angles["right_elbow"] = calculate_angle(joints["right_shoulder"], joints["right_elbow"], joints["right_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_hip"]):
            angles["left_arm_lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_hip"])
        if all(k in joints for k in ["right_elbow", "right_shoulder", "right_hip"]):
            angles["right_arm_lift"] = calculate_angle(joints["right_elbow"], joints["right_shoulder"], joints["right_hip"])
        if mid_shoulder and "nose" in joints:
            angles["neck_angle"] = calculate_angle(joints["nose"], mid_shoulder, joints["left_shoulder"])

        return angles
    
    return None

# Open webcam
cap = cv2.VideoCapture(0)

for move in moves:
    move_name = move["name"]
    duration = move["duration"]
    
    print(f"Get ready for move: {move_name}")
    time.sleep(2)  # Give user time to prepare
    
    print(f"Recording move: {move_name} (duration: {duration}s)...")
    
    start_time = time.time()
    capture_time = start_time + (duration / 2)  # Capture a frame at the middle of the move
    
    captured_frame = None

    while time.time() - start_time < duration:
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame!")
            continue
        
        if time.time() >= capture_time and captured_frame is None:
            captured_frame = frame.copy()
    
    if captured_frame is not None:
        angles = process_frame(captured_frame)
        if angles:
            # Save angles for this move
            with open(os.path.join(output_dir, f"{move_name}.json"), "w") as f:
                json.dump(angles, f, indent=4)
            print(f"Saved reference angles for {move_name}")
        else:
            print(f"Failed to detect pose for {move_name}")

cap.release()
cv2.destroyAllWindows()
# Out:
# Get ready for move: asitwas_jacket
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 92
#      89 duration = move["duration"]
#      91 print(f"Get ready for move: {move_name}")
# ---> 92 time.sleep(2)  # Give user time to prepare
#      94 print(f"Recording move: {move_name} (duration: {duration}s)...")
#      96 start_time = time.time()
#
# KeyboardInterrupt:

# %%
## 1 Frame Data Recorded for each move ##

import cv2
import mediapipe as mp
import json
import numpy as np
import time
import os
import joblib

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

# Extract moves
moves = timeline_data["moves"]

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Directory to save processed reference data
output_dir = "reference_moves"
os.makedirs(output_dir, exist_ok=True)

# Load the dance video
video_path = "asitwas.webm"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

def calculate_angle(a, b, c):
    """Calculate angle between three 3D points using the arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))

    return np.degrees(angle)

def process_frame(image):
    """Extract pose landmarks from a frame and compute angles."""
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Extract key joint coordinates (normalized values)
        joint_ids = {
            "nose": 0,
            "left_shoulder": 11, "right_shoulder": 12,
            "left_elbow": 13, "right_elbow": 14,
            "left_wrist": 15, "right_wrist": 16,
            "left_hip": 23, "right_hip": 24
        }

        joints = {name: (landmarks[idx].x, landmarks[idx].y, landmarks[idx].z) for name, idx in joint_ids.items()}

        # Compute mid-shoulder point
        if "left_shoulder" in joints and "right_shoulder" in joints:
            mid_shoulder = (
                (joints["left_shoulder"][0] + joints["right_shoulder"][0]) / 2,
                (joints["left_shoulder"][1] + joints["right_shoulder"][1]) / 2,
                (joints["left_shoulder"][2] + joints["right_shoulder"][2]) / 2
            )
        else:
            mid_shoulder = None

        # Compute angles
        angles = {}

        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["left_elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["right_shoulder", "right_elbow", "right_wrist"]):
            angles["right_elbow"] = calculate_angle(joints["right_shoulder"], joints["right_elbow"], joints["right_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_hip"]):
            angles["left_arm_lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_hip"])
        if all(k in joints for k in ["right_elbow", "right_shoulder", "right_hip"]):
            angles["right_arm_lift"] = calculate_angle(joints["right_elbow"], joints["right_shoulder"], joints["right_hip"])
        if mid_shoulder and "nose" in joints:
            angles["neck_angle"] = calculate_angle(joints["nose"], mid_shoulder, joints["left_shoulder"])

        return {"joints": joints, "angles": angles}

    return None

# Process each move in the timeline
reference_data = {}

for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 14.828
    duration = move["duration"]

    mid_time = start_time + (duration / 2)  # Middle of the move

    frame_idx = int(mid_time * fps)  # Convert to frame index
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # Seek to the frame

    ret, frame = cap.read()
    if not ret:
        print(f"Failed to capture frame for {move_name} at time {mid_time}s (frame {frame_idx})!")
        continue

    print(f"Processing {move_name} at frame {frame_idx}...")

    pose_data = process_frame(frame)
    if pose_data:
        reference_data[move_name] = pose_data
        print(f"✔ Saved pose data for {move_name}")
    else:
        print(f"❌ Failed to detect pose for {move_name}")

# Save the reference data using joblib
joblib.dump(reference_data, os.path.join(output_dir, "reference_data.pkl"))
print(f"✅ Reference data saved to {output_dir}/reference_data.pkl")

cap.release()
cv2.destroyAllWindows()
# Out:
# Video FPS: 25.0
# Processing asitwas_jacket at frame 495...
# ✔ Saved pose data for asitwas_jacket
# Processing asitwas_snap at frame 513...
# ✔ Saved pose data for asitwas_snap
# Processing asitwas_arm_up at frame 532...
# ✔ Saved pose data for asitwas_arm_up
# Processing asitwas_snap_down_start at frame 590...
# ✔ Saved pose data for asitwas_snap_down_start
# Processing asitwas_snap_down at frame 607...
# ✔ Saved pose data for asitwas_snap_down
# Processing asitwas_snap_down at frame 625...
# ✔ Saved pose data for asitwas_snap_down
# Processing asitwas_snap_down at frame 642...
# ✔ Saved pose data for asitwas_snap_down
# Processing asitwas_snap_down_start_2 at frame 659...
# ✔ Saved pose data for asitwas_snap_down_start_2
# Processing asitwas_snap_down at frame 676...
# ✔ Saved pose data for asitwas_snap_down
# Processing asitwas_snap_down at frame 694...
# ✔ Saved pose data for asitwas_snap_down
# Processing asitwas_snap_down_end at frame 711...
# ✔ Saved pose data for asitwas_snap_down_end
# Processing asitwas_arm_down at frame 728...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 745...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 763...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_arm_down at frame 797...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 814...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 831...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_circle at frame 866...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 900...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_circle at frame 935...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 969...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_arm_down at frame 1004...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 1021...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 1038...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_arm_down at frame 1073...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 1090...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 1107...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_circle at frame 1142...
# ❌ Failed to detect pose for asitwas_circle
# Processing asitwas_circle_2 at frame 1176...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_circle at frame 1211...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 1245...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_cross_arm at frame 1280...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 1297...
# ✔ Saved pose data for asitwas_arm_fall
# Processing asitwas_belly at frame 1312...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 1325...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1340...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1357...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1381...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 1394...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1409...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1426...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1450...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 1463...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_hips at frame 1478...
# ✔ Saved pose data for asitwas_hips
# Processing asitwas_hips_2 at frame 1495...
# ✔ Saved pose data for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 1517...
# ✔ Saved pose data for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 1534...
# ✔ Saved pose data for asitwas_snap_chorus_2
# Processing asitwas_cross_arm at frame 1556...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 1573...
# ✔ Saved pose data for asitwas_arm_fall
# Processing asitwas_belly at frame 1588...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 1601...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1616...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1633...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1657...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 1670...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1685...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1702...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1726...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 1739...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_hips at frame 1754...
# ✔ Saved pose data for asitwas_hips
# Processing asitwas_hips_2 at frame 1771...
# ✔ Saved pose data for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 1793...
# ✔ Saved pose data for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 1810...
# ✔ Saved pose data for asitwas_snap_chorus_2
# Processing asitwas_drum at frame 1831...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 1849...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 1866...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 1883...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_hi at frame 1900...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 1935...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_drum at frame 1969...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 1987...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 2004...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 2021...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_hi at frame 2038...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 2073...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_arm_down at frame 2107...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 2125...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 2142...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_arm_down at frame 2176...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 2194...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 2211...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_circle at frame 2245...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 2280...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_circle at frame 2314...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 2349...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_arm_down at frame 2383...
# ❌ Failed to detect pose for asitwas_arm_down
# Processing asitwas_sun at frame 2400...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 2418...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_arm_down at frame 2452...
# ✔ Saved pose data for asitwas_arm_down
# Processing asitwas_sun at frame 2469...
# ✔ Saved pose data for asitwas_sun
# Processing asitwas_fists at frame 2487...
# ✔ Saved pose data for asitwas_fists
# Processing asitwas_circle at frame 2521...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 2556...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_circle at frame 2590...
# ✔ Saved pose data for asitwas_circle
# Processing asitwas_circle_2 at frame 2625...
# ✔ Saved pose data for asitwas_circle_2
# Processing asitwas_cross_arm at frame 2659...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 2676...
# ✔ Saved pose data for asitwas_arm_fall
# Processing asitwas_belly at frame 2691...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 2704...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 2719...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 2737...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 2760...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 2773...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 2788...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 2806...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 2829...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 2842...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_hips at frame 2857...
# ✔ Saved pose data for asitwas_hips
# Processing asitwas_hips_2 at frame 2875...
# ✔ Saved pose data for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 2896...
# ✔ Saved pose data for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 2913...
# ✔ Saved pose data for asitwas_snap_chorus_2
# Processing asitwas_cross_arm at frame 2935...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 2952...
# ✔ Saved pose data for asitwas_arm_fall
# Processing asitwas_belly at frame 2967...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 2980...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 2995...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 3013...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 3036...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 3049...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_cross_arm at frame 3064...
# ✔ Saved pose data for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 3081...
# ✔ Saved pose data for asitwas_arm_fall_2
# Processing asitwas_belly at frame 3105...
# ✔ Saved pose data for asitwas_belly
# Processing asitwas_belly_2 at frame 3118...
# ✔ Saved pose data for asitwas_belly_2
# Processing asitwas_hips at frame 3133...
# ✔ Saved pose data for asitwas_hips
# Processing asitwas_hips_2 at frame 3150...
# ✔ Saved pose data for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 3172...
# ✔ Saved pose data for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 3189...
# ✔ Saved pose data for asitwas_snap_chorus_2
# Processing asitwas_drum at frame 3211...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3228...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3245...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3263...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_hi at frame 3280...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 3314...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_drum at frame 3349...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3366...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3383...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3400...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_hi at frame 3418...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 3452...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_run at frame 3487...
# ✔ Saved pose data for asitwas_run
# Processing asitwas_hair at frame 3504...
# ❌ Failed to detect pose for asitwas_hair
# Processing asitwas_run at frame 3521...
# ✔ Saved pose data for asitwas_run
# Processing asitwas_hair at frame 3538...
# ❌ Failed to detect pose for asitwas_hair
# Processing asitwas_jacket_2_start at frame 3556...
# ✔ Saved pose data for asitwas_jacket_2_start
# Processing asitwas_jacket_2 at frame 3573...
# ✔ Saved pose data for asitwas_jacket_2
# Processing asitwas_jacket_2 at frame 3590...
# ✔ Saved pose data for asitwas_jacket_2
# Processing asitwas_jacket_2 at frame 3607...
# ✔ Saved pose data for asitwas_jacket_2
# Processing asitwas_run at frame 3625...
# ✔ Saved pose data for asitwas_run
# Processing asitwas_hair at frame 3642...
# ✔ Saved pose data for asitwas_hair
# Processing asitwas_run at frame 3659...
# ✔ Saved pose data for asitwas_run
# Processing asitwas_hair at frame 3676...
# ✔ Saved pose data for asitwas_hair
# Processing asitwas_jacket_2_start at frame 3694...
# ✔ Saved pose data for asitwas_jacket_2_start
# Processing asitwas_jacket_2 at frame 3711...
# ✔ Saved pose data for asitwas_jacket_2
# Processing asitwas_jacket_2 at frame 3728...
# ✔ Saved pose data for asitwas_jacket_2
# Processing asitwas_jacket_end at frame 3745...
# ✔ Saved pose data for asitwas_jacket_end
# Processing asitwas_hands at frame 3763...
# ✔ Saved pose data for asitwas_hands
# Processing asitwas_hands_2 at frame 3780...
# ✔ Saved pose data for asitwas_hands_2
# Processing asitwas_head_down at frame 3806...
# ✔ Saved pose data for asitwas_head_down
# Processing asitwas_jump at frame 3823...
# ✔ Saved pose data for asitwas_jump
# Processing asitwas_knee at frame 3883...
# ✔ Saved pose data for asitwas_knee
# Processing asitwas_hi at frame 3900...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 3935...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_drum at frame 3969...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 3987...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4004...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4021...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_hi at frame 4038...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 4073...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_drum at frame 4107...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4125...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4142...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4159...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_hi at frame 4176...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_hi at frame 4211...
# ✔ Saved pose data for asitwas_hi
# Processing asitwas_drum at frame 4245...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4263...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4280...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_drum at frame 4297...
# ✔ Saved pose data for asitwas_drum
# Processing asitwas_arms_open at frame 4314...
# ✔ Saved pose data for asitwas_arms_open
# Processing asitwas_arms_close at frame 4353...
# ✔ Saved pose data for asitwas_arms_close
# Processing asitwas_final_pose at frame 4370...
# ✔ Saved pose data for asitwas_final_pose
# ✅ Reference data saved to reference_moves/reference_data.pkl

# %%
## 3 Frame Data Recorded for each move (just left hand)##

import cv2
import mediapipe as mp
import json
import numpy as np
import os
import joblib

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

# Extract moves
moves = timeline_data["moves"]

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Directory to save processed reference data
output_dir = "reference_moves_three"
os.makedirs(output_dir, exist_ok=True)

# Load the dance video
video_path = "asitwas.webm"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

def calculate_angle(a, b, c):
    """Calculate angle between three 3D points using the arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))

    return np.degrees(angle)

def process_frame(image):
    """Extract pose landmarks from a frame and compute only left elbow and left arm lift angles."""
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Extract key joint coordinates (normalized values)
        joint_ids = {
            "left_shoulder": 11,
            "left_elbow": 13,
            "left_wrist": 15,
            "left_hip": 23
        }

        joints = {name: (landmarks[idx].x, landmarks[idx].y, landmarks[idx].z) for name, idx in joint_ids.items()}

        # Compute angles
        angles = {}

        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["left_elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_hip"]):
            angles["left_arm_lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_hip"])

        return {"joints": joints, "angles": angles}

    return None



# Process each move in the timeline
reference_data = {}

for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 14.828  # Adjust offset if needed
    duration = move["duration"]

    # Get three frames: start, middle, end
    frame_times = [
        start_time,  # Start frame
        start_time + (duration / 2),  # Middle frame
        start_time + duration  # End frame
    ]

    move_data = []  # Store all frames for this move

    for time_point in frame_times:
        frame_idx = int(time_point * fps)  # Convert to frame index
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # Seek to the frame

        ret, frame = cap.read()
        if not ret:
            print(f"❌ Failed to capture frame for {move_name} at {time_point}s (frame {frame_idx})")
            continue

        print(f"Processing {move_name} at frame {frame_idx}...")

        pose_data = process_frame(frame)
        if pose_data:
            move_data.append(pose_data)
        else:
            print(f"❌ Failed to detect pose for {move_name} at frame {frame_idx}")

    if move_data:
        reference_data[move_name] = move_data
        print(f"✔ Saved {len(move_data)} frames for {move_name}")
    else:
        print(f"❌ No valid pose data for {move_name}")

# Save the reference data using joblib
joblib.dump(reference_data, os.path.join(output_dir, "reference_data.pkl"))
print(f"✅ Reference data saved to {output_dir}/reference_data.pkl")

cap.release()
cv2.destroyAllWindows()
# Out:
# Video FPS: 25.0
# Processing asitwas_jacket at frame 487...
# Processing asitwas_jacket at frame 495...
# Processing asitwas_jacket at frame 504...
# ✔ Saved 3 frames for asitwas_jacket
# Processing asitwas_snap at frame 504...
# Processing asitwas_snap at frame 513...
# Processing asitwas_snap at frame 521...
# ✔ Saved 3 frames for asitwas_snap
# Processing asitwas_arm_up at frame 521...
# Processing asitwas_arm_up at frame 532...
# Processing asitwas_arm_up at frame 543...
# ✔ Saved 3 frames for asitwas_arm_up
# Processing asitwas_snap_down_start at frame 581...
# Processing asitwas_snap_down_start at frame 590...
# Processing asitwas_snap_down_start at frame 599...
# ✔ Saved 3 frames for asitwas_snap_down_start
# Processing asitwas_snap_down at frame 599...
# Processing asitwas_snap_down at frame 607...
# Processing asitwas_snap_down at frame 616...
# ✔ Saved 3 frames for asitwas_snap_down
# Processing asitwas_snap_down at frame 616...
# Processing asitwas_snap_down at frame 625...
# Processing asitwas_snap_down at frame 633...
# ✔ Saved 3 frames for asitwas_snap_down
# Processing asitwas_snap_down at frame 633...
# Processing asitwas_snap_down at frame 642...
# Processing asitwas_snap_down at frame 651...
# ✔ Saved 3 frames for asitwas_snap_down
# Processing asitwas_snap_down_start_2 at frame 650...
# Processing asitwas_snap_down_start_2 at frame 659...
# Processing asitwas_snap_down_start_2 at frame 668...
# ✔ Saved 3 frames for asitwas_snap_down_start_2
# Processing asitwas_snap_down at frame 668...
# Processing asitwas_snap_down at frame 676...
# Processing asitwas_snap_down at frame 685...
# ✔ Saved 3 frames for asitwas_snap_down
# Processing asitwas_snap_down at frame 685...
# Processing asitwas_snap_down at frame 694...
# Processing asitwas_snap_down at frame 702...
# ✔ Saved 3 frames for asitwas_snap_down
# Processing asitwas_snap_down_end at frame 702...
# Processing asitwas_snap_down_end at frame 711...
# Processing asitwas_snap_down_end at frame 719...
# ✔ Saved 3 frames for asitwas_snap_down_end
# Processing asitwas_arm_down at frame 719...
# Processing asitwas_arm_down at frame 728...
# Processing asitwas_arm_down at frame 737...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 737...
# Processing asitwas_sun at frame 745...
# Processing asitwas_sun at frame 754...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 754...
# Processing asitwas_fists at frame 763...
# Processing asitwas_fists at frame 771...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_arm_down at frame 788...
# Processing asitwas_arm_down at frame 797...
# Processing asitwas_arm_down at frame 806...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 806...
# Processing asitwas_sun at frame 814...
# Processing asitwas_sun at frame 823...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 823...
# Processing asitwas_fists at frame 831...
# Processing asitwas_fists at frame 840...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_circle at frame 857...
# Processing asitwas_circle at frame 866...
# Processing asitwas_circle at frame 875...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 892...
# Processing asitwas_circle_2 at frame 900...
# Processing asitwas_circle_2 at frame 909...
# ✔ Saved 3 frames for asitwas_circle_2
# Processing asitwas_circle at frame 926...
# Processing asitwas_circle at frame 935...
# Processing asitwas_circle at frame 944...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 961...
# Processing asitwas_circle_2 at frame 969...
# Processing asitwas_circle_2 at frame 978...
# ✔ Saved 3 frames for asitwas_circle_2
# Processing asitwas_arm_down at frame 995...
# Processing asitwas_arm_down at frame 1004...
# Processing asitwas_arm_down at frame 1013...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 1012...
# Processing asitwas_sun at frame 1021...
# Processing asitwas_sun at frame 1030...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 1030...
# Processing asitwas_fists at frame 1038...
# Processing asitwas_fists at frame 1047...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_arm_down at frame 1064...
# Processing asitwas_arm_down at frame 1073...
# Processing asitwas_arm_down at frame 1082...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 1081...
# Processing asitwas_sun at frame 1090...
# Processing asitwas_sun at frame 1099...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 1099...
# Processing asitwas_fists at frame 1107...
# Processing asitwas_fists at frame 1116...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_circle at frame 1133...
# Processing asitwas_circle at frame 1142...
# Processing asitwas_circle at frame 1151...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 1168...
# Processing asitwas_circle_2 at frame 1176...
# Processing asitwas_circle_2 at frame 1185...
# ❌ Failed to detect pose for asitwas_circle_2 at frame 1185
# ✔ Saved 2 frames for asitwas_circle_2
# Processing asitwas_circle at frame 1202...
# Processing asitwas_circle at frame 1211...
# Processing asitwas_circle at frame 1219...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 1237...
# Processing asitwas_circle_2 at frame 1245...
# Processing asitwas_circle_2 at frame 1254...
# ✔ Saved 3 frames for asitwas_circle_2
# Processing asitwas_cross_arm at frame 1271...
# Processing asitwas_cross_arm at frame 1280...
# Processing asitwas_cross_arm at frame 1288...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 1288...
# Processing asitwas_arm_fall at frame 1297...
# Processing asitwas_arm_fall at frame 1306...
# ✔ Saved 3 frames for asitwas_arm_fall
# Processing asitwas_belly at frame 1306...
# Processing asitwas_belly at frame 1312...
# Processing asitwas_belly at frame 1319...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 1318...
# Processing asitwas_belly_2 at frame 1325...
# Processing asitwas_belly_2 at frame 1332...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1331...
# Processing asitwas_cross_arm at frame 1340...
# Processing asitwas_cross_arm at frame 1349...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1349...
# Processing asitwas_arm_fall_2 at frame 1357...
# Processing asitwas_arm_fall_2 at frame 1366...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1375...
# Processing asitwas_belly at frame 1381...
# Processing asitwas_belly at frame 1388...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 1387...
# Processing asitwas_belly_2 at frame 1394...
# Processing asitwas_belly_2 at frame 1400...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1400...
# Processing asitwas_cross_arm at frame 1409...
# Processing asitwas_cross_arm at frame 1418...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1418...
# Processing asitwas_arm_fall_2 at frame 1426...
# Processing asitwas_arm_fall_2 at frame 1435...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1443...
# Processing asitwas_belly at frame 1450...
# Processing asitwas_belly at frame 1457...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 1456...
# Processing asitwas_belly_2 at frame 1463...
# Processing asitwas_belly_2 at frame 1469...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_hips at frame 1469...
# Processing asitwas_hips at frame 1478...
# Processing asitwas_hips at frame 1487...
# ✔ Saved 3 frames for asitwas_hips
# Processing asitwas_hips_2 at frame 1487...
# Processing asitwas_hips_2 at frame 1495...
# Processing asitwas_hips_2 at frame 1504...
# ✔ Saved 3 frames for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 1508...
# Processing asitwas_snap_chorus at frame 1517...
# Processing asitwas_snap_chorus at frame 1526...
# ✔ Saved 3 frames for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 1525...
# Processing asitwas_snap_chorus_2 at frame 1534...
# Processing asitwas_snap_chorus_2 at frame 1543...
# ✔ Saved 3 frames for asitwas_snap_chorus_2
# Processing asitwas_cross_arm at frame 1547...
# Processing asitwas_cross_arm at frame 1556...
# Processing asitwas_cross_arm at frame 1564...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 1564...
# Processing asitwas_arm_fall at frame 1573...
# Processing asitwas_arm_fall at frame 1582...
# ✔ Saved 3 frames for asitwas_arm_fall
# Processing asitwas_belly at frame 1581...
# Processing asitwas_belly at frame 1588...
# Processing asitwas_belly at frame 1594...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 1594...
# Processing asitwas_belly_2 at frame 1601...
# Processing asitwas_belly_2 at frame 1607...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1607...
# Processing asitwas_cross_arm at frame 1616...
# Processing asitwas_cross_arm at frame 1625...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1625...
# Processing asitwas_arm_fall_2 at frame 1633...
# Processing asitwas_arm_fall_2 at frame 1642...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1650...
# Processing asitwas_belly at frame 1657...
# Processing asitwas_belly at frame 1663...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 1663...
# Processing asitwas_belly_2 at frame 1670...
# Processing asitwas_belly_2 at frame 1676...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 1676...
# Processing asitwas_cross_arm at frame 1685...
# Processing asitwas_cross_arm at frame 1694...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 1693...
# Processing asitwas_arm_fall_2 at frame 1702...
# Processing asitwas_arm_fall_2 at frame 1711...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 1719...
# Processing asitwas_belly at frame 1726...
# Processing asitwas_belly at frame 1732...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 1732...
# Processing asitwas_belly_2 at frame 1739...
# Processing asitwas_belly_2 at frame 1745...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_hips at frame 1745...
# Processing asitwas_hips at frame 1754...
# Processing asitwas_hips at frame 1763...
# ✔ Saved 3 frames for asitwas_hips
# Processing asitwas_hips_2 at frame 1762...
# Processing asitwas_hips_2 at frame 1771...
# Processing asitwas_hips_2 at frame 1780...
# ✔ Saved 3 frames for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 1784...
# Processing asitwas_snap_chorus at frame 1793...
# Processing asitwas_snap_chorus at frame 1801...
# ✔ Saved 3 frames for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 1801...
# Processing asitwas_snap_chorus_2 at frame 1810...
# Processing asitwas_snap_chorus_2 at frame 1819...
# ✔ Saved 3 frames for asitwas_snap_chorus_2
# Processing asitwas_drum at frame 1823...
# Processing asitwas_drum at frame 1831...
# Processing asitwas_drum at frame 1840...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 1840...
# Processing asitwas_drum at frame 1849...
# Processing asitwas_drum at frame 1857...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 1857...
# Processing asitwas_drum at frame 1866...
# Processing asitwas_drum at frame 1875...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 1875...
# Processing asitwas_drum at frame 1883...
# Processing asitwas_drum at frame 1892...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_hi at frame 1892...
# Processing asitwas_hi at frame 1900...
# Processing asitwas_hi at frame 1909...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 1926...
# Processing asitwas_hi at frame 1935...
# Processing asitwas_hi at frame 1944...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_drum at frame 1961...
# Processing asitwas_drum at frame 1969...
# Processing asitwas_drum at frame 1978...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 1978...
# Processing asitwas_drum at frame 1987...
# Processing asitwas_drum at frame 1995...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 1995...
# Processing asitwas_drum at frame 2004...
# Processing asitwas_drum at frame 2013...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 2012...
# Processing asitwas_drum at frame 2021...
# Processing asitwas_drum at frame 2030...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_hi at frame 2030...
# Processing asitwas_hi at frame 2038...
# Processing asitwas_hi at frame 2047...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 2064...
# Processing asitwas_hi at frame 2073...
# Processing asitwas_hi at frame 2082...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_arm_down at frame 2099...
# Processing asitwas_arm_down at frame 2107...
# Processing asitwas_arm_down at frame 2116...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 2116...
# Processing asitwas_sun at frame 2125...
# Processing asitwas_sun at frame 2133...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 2133...
# Processing asitwas_fists at frame 2142...
# Processing asitwas_fists at frame 2151...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_arm_down at frame 2168...
# Processing asitwas_arm_down at frame 2176...
# Processing asitwas_arm_down at frame 2185...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 2185...
# Processing asitwas_sun at frame 2194...
# Processing asitwas_sun at frame 2202...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 2202...
# Processing asitwas_fists at frame 2211...
# Processing asitwas_fists at frame 2219...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_circle at frame 2237...
# Processing asitwas_circle at frame 2245...
# Processing asitwas_circle at frame 2254...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 2271...
# Processing asitwas_circle_2 at frame 2280...
# Processing asitwas_circle_2 at frame 2288...
# ❌ Failed to detect pose for asitwas_circle_2 at frame 2288
# ✔ Saved 2 frames for asitwas_circle_2
# Processing asitwas_circle at frame 2306...
# Processing asitwas_circle at frame 2314...
# Processing asitwas_circle at frame 2323...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 2340...
# Processing asitwas_circle_2 at frame 2349...
# Processing asitwas_circle_2 at frame 2357...
# ✔ Saved 3 frames for asitwas_circle_2
# Processing asitwas_arm_down at frame 2375...
# Processing asitwas_arm_down at frame 2383...
# Processing asitwas_arm_down at frame 2392...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 2392...
# Processing asitwas_sun at frame 2400...
# Processing asitwas_sun at frame 2409...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 2409...
# Processing asitwas_fists at frame 2418...
# Processing asitwas_fists at frame 2426...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_arm_down at frame 2443...
# Processing asitwas_arm_down at frame 2452...
# Processing asitwas_arm_down at frame 2461...
# ✔ Saved 3 frames for asitwas_arm_down
# Processing asitwas_sun at frame 2461...
# Processing asitwas_sun at frame 2469...
# Processing asitwas_sun at frame 2478...
# ✔ Saved 3 frames for asitwas_sun
# Processing asitwas_fists at frame 2478...
# Processing asitwas_fists at frame 2487...
# Processing asitwas_fists at frame 2495...
# ✔ Saved 3 frames for asitwas_fists
# Processing asitwas_circle at frame 2512...
# Processing asitwas_circle at frame 2521...
# Processing asitwas_circle at frame 2530...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 2547...
# Processing asitwas_circle_2 at frame 2556...
# ❌ Failed to detect pose for asitwas_circle_2 at frame 2556
# Processing asitwas_circle_2 at frame 2564...
# ✔ Saved 2 frames for asitwas_circle_2
# Processing asitwas_circle at frame 2581...
# Processing asitwas_circle at frame 2590...
# Processing asitwas_circle at frame 2599...
# ✔ Saved 3 frames for asitwas_circle
# Processing asitwas_circle_2 at frame 2616...
# Processing asitwas_circle_2 at frame 2625...
# Processing asitwas_circle_2 at frame 2633...
# ✔ Saved 3 frames for asitwas_circle_2
# Processing asitwas_cross_arm at frame 2650...
# Processing asitwas_cross_arm at frame 2659...
# Processing asitwas_cross_arm at frame 2668...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 2668...
# Processing asitwas_arm_fall at frame 2676...
# Processing asitwas_arm_fall at frame 2685...
# ✔ Saved 3 frames for asitwas_arm_fall
# Processing asitwas_belly at frame 2685...
# Processing asitwas_belly at frame 2691...
# Processing asitwas_belly at frame 2698...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 2698...
# Processing asitwas_belly_2 at frame 2704...
# Processing asitwas_belly_2 at frame 2711...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 2711...
# Processing asitwas_cross_arm at frame 2719...
# Processing asitwas_cross_arm at frame 2728...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 2728...
# Processing asitwas_arm_fall_2 at frame 2737...
# Processing asitwas_arm_fall_2 at frame 2745...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 2754...
# Processing asitwas_belly at frame 2760...
# Processing asitwas_belly at frame 2767...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 2767...
# Processing asitwas_belly_2 at frame 2773...
# Processing asitwas_belly_2 at frame 2780...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 2780...
# Processing asitwas_cross_arm at frame 2788...
# Processing asitwas_cross_arm at frame 2797...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 2797...
# Processing asitwas_arm_fall_2 at frame 2806...
# Processing asitwas_arm_fall_2 at frame 2814...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 2823...
# Processing asitwas_belly at frame 2829...
# Processing asitwas_belly at frame 2836...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 2836...
# Processing asitwas_belly_2 at frame 2842...
# Processing asitwas_belly_2 at frame 2849...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_hips at frame 2849...
# Processing asitwas_hips at frame 2857...
# Processing asitwas_hips at frame 2866...
# ✔ Saved 3 frames for asitwas_hips
# Processing asitwas_hips_2 at frame 2866...
# Processing asitwas_hips_2 at frame 2875...
# Processing asitwas_hips_2 at frame 2883...
# ✔ Saved 3 frames for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 2887...
# Processing asitwas_snap_chorus at frame 2896...
# Processing asitwas_snap_chorus at frame 2905...
# ✔ Saved 3 frames for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 2905...
# Processing asitwas_snap_chorus_2 at frame 2913...
# Processing asitwas_snap_chorus_2 at frame 2922...
# ✔ Saved 3 frames for asitwas_snap_chorus_2
# Processing asitwas_cross_arm at frame 2926...
# Processing asitwas_cross_arm at frame 2935...
# Processing asitwas_cross_arm at frame 2944...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall at frame 2943...
# Processing asitwas_arm_fall at frame 2952...
# Processing asitwas_arm_fall at frame 2961...
# ✔ Saved 3 frames for asitwas_arm_fall
# Processing asitwas_belly at frame 2961...
# Processing asitwas_belly at frame 2967...
# Processing asitwas_belly at frame 2974...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 2974...
# Processing asitwas_belly_2 at frame 2980...
# Processing asitwas_belly_2 at frame 2987...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 2987...
# Processing asitwas_cross_arm at frame 2995...
# Processing asitwas_cross_arm at frame 3004...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 3004...
# Processing asitwas_arm_fall_2 at frame 3013...
# Processing asitwas_arm_fall_2 at frame 3021...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 3030...
# Processing asitwas_belly at frame 3036...
# Processing asitwas_belly at frame 3043...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 3043...
# Processing asitwas_belly_2 at frame 3049...
# Processing asitwas_belly_2 at frame 3056...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_cross_arm at frame 3056...
# Processing asitwas_cross_arm at frame 3064...
# Processing asitwas_cross_arm at frame 3073...
# ✔ Saved 3 frames for asitwas_cross_arm
# Processing asitwas_arm_fall_2 at frame 3073...
# Processing asitwas_arm_fall_2 at frame 3081...
# Processing asitwas_arm_fall_2 at frame 3090...
# ✔ Saved 3 frames for asitwas_arm_fall_2
# Processing asitwas_belly at frame 3099...
# Processing asitwas_belly at frame 3105...
# Processing asitwas_belly at frame 3112...
# ✔ Saved 3 frames for asitwas_belly
# Processing asitwas_belly_2 at frame 3112...
# Processing asitwas_belly_2 at frame 3118...
# Processing asitwas_belly_2 at frame 3125...
# ✔ Saved 3 frames for asitwas_belly_2
# Processing asitwas_hips at frame 3125...
# Processing asitwas_hips at frame 3133...
# Processing asitwas_hips at frame 3142...
# ✔ Saved 3 frames for asitwas_hips
# Processing asitwas_hips_2 at frame 3142...
# Processing asitwas_hips_2 at frame 3150...
# Processing asitwas_hips_2 at frame 3159...
# ✔ Saved 3 frames for asitwas_hips_2
# Processing asitwas_snap_chorus at frame 3163...
# Processing asitwas_snap_chorus at frame 3172...
# Processing asitwas_snap_chorus at frame 3181...
# ✔ Saved 3 frames for asitwas_snap_chorus
# Processing asitwas_snap_chorus_2 at frame 3181...
# Processing asitwas_snap_chorus_2 at frame 3189...
# Processing asitwas_snap_chorus_2 at frame 3198...
# ✔ Saved 3 frames for asitwas_snap_chorus_2
# Processing asitwas_drum at frame 3202...
# Processing asitwas_drum at frame 3211...
# Processing asitwas_drum at frame 3219...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3219...
# Processing asitwas_drum at frame 3228...
# Processing asitwas_drum at frame 3237...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3237...
# Processing asitwas_drum at frame 3245...
# Processing asitwas_drum at frame 3254...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3254...
# Processing asitwas_drum at frame 3263...
# Processing asitwas_drum at frame 3271...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_hi at frame 3271...
# Processing asitwas_hi at frame 3280...
# Processing asitwas_hi at frame 3288...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 3306...
# Processing asitwas_hi at frame 3314...
# Processing asitwas_hi at frame 3323...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_drum at frame 3340...
# Processing asitwas_drum at frame 3349...
# Processing asitwas_drum at frame 3357...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3357...
# Processing asitwas_drum at frame 3366...
# Processing asitwas_drum at frame 3375...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3375...
# Processing asitwas_drum at frame 3383...
# Processing asitwas_drum at frame 3392...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3392...
# Processing asitwas_drum at frame 3400...
# Processing asitwas_drum at frame 3409...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_hi at frame 3409...
# Processing asitwas_hi at frame 3418...
# Processing asitwas_hi at frame 3426...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 3443...
# Processing asitwas_hi at frame 3452...
# Processing asitwas_hi at frame 3461...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_run at frame 3478...
# Processing asitwas_run at frame 3487...
# Processing asitwas_run at frame 3495...
# ✔ Saved 3 frames for asitwas_run
# Processing asitwas_hair at frame 3495...
# Processing asitwas_hair at frame 3504...
# Processing asitwas_hair at frame 3513...
# ✔ Saved 3 frames for asitwas_hair
# Processing asitwas_run at frame 3512...
# Processing asitwas_run at frame 3521...
# Processing asitwas_run at frame 3530...
# ✔ Saved 3 frames for asitwas_run
# Processing asitwas_hair at frame 3530...
# Processing asitwas_hair at frame 3538...
# ❌ Failed to detect pose for asitwas_hair at frame 3538
# Processing asitwas_hair at frame 3547...
# ✔ Saved 2 frames for asitwas_hair
# Processing asitwas_jacket_2_start at frame 3547...
# Processing asitwas_jacket_2_start at frame 3556...
# Processing asitwas_jacket_2_start at frame 3564...
# ✔ Saved 3 frames for asitwas_jacket_2_start
# Processing asitwas_jacket_2 at frame 3564...
# Processing asitwas_jacket_2 at frame 3573...
# Processing asitwas_jacket_2 at frame 3582...
# ✔ Saved 3 frames for asitwas_jacket_2
# Processing asitwas_jacket_2 at frame 3581...
# Processing asitwas_jacket_2 at frame 3590...
# Processing asitwas_jacket_2 at frame 3599...
# ✔ Saved 3 frames for asitwas_jacket_2
# Processing asitwas_jacket_2 at frame 3599...
# Processing asitwas_jacket_2 at frame 3607...
# Processing asitwas_jacket_2 at frame 3616...
# ✔ Saved 3 frames for asitwas_jacket_2
# Processing asitwas_run at frame 3616...
# Processing asitwas_run at frame 3625...
# Processing asitwas_run at frame 3633...
# ✔ Saved 3 frames for asitwas_run
# Processing asitwas_hair at frame 3633...
# Processing asitwas_hair at frame 3642...
# Processing asitwas_hair at frame 3651...
# ✔ Saved 3 frames for asitwas_hair
# Processing asitwas_run at frame 3650...
# Processing asitwas_run at frame 3659...
# Processing asitwas_run at frame 3668...
# ✔ Saved 3 frames for asitwas_run
# Processing asitwas_hair at frame 3668...
# Processing asitwas_hair at frame 3676...
# Processing asitwas_hair at frame 3685...
# ✔ Saved 3 frames for asitwas_hair
# Processing asitwas_jacket_2_start at frame 3685...
# Processing asitwas_jacket_2_start at frame 3694...
# Processing asitwas_jacket_2_start at frame 3702...
# ✔ Saved 3 frames for asitwas_jacket_2_start
# Processing asitwas_jacket_2 at frame 3702...
# Processing asitwas_jacket_2 at frame 3711...
# Processing asitwas_jacket_2 at frame 3719...
# ✔ Saved 3 frames for asitwas_jacket_2
# Processing asitwas_jacket_2 at frame 3719...
# Processing asitwas_jacket_2 at frame 3728...
# Processing asitwas_jacket_2 at frame 3737...
# ✔ Saved 3 frames for asitwas_jacket_2
# Processing asitwas_jacket_end at frame 3737...
# Processing asitwas_jacket_end at frame 3745...
# Processing asitwas_jacket_end at frame 3754...
# ✔ Saved 3 frames for asitwas_jacket_end
# Processing asitwas_hands at frame 3754...
# Processing asitwas_hands at frame 3763...
# Processing asitwas_hands at frame 3771...
# ✔ Saved 3 frames for asitwas_hands
# Processing asitwas_hands_2 at frame 3771...
# Processing asitwas_hands_2 at frame 3780...
# Processing asitwas_hands_2 at frame 3788...
# ✔ Saved 3 frames for asitwas_hands_2
# Processing asitwas_head_down at frame 3797...
# Processing asitwas_head_down at frame 3806...
# Processing asitwas_head_down at frame 3814...
# ✔ Saved 3 frames for asitwas_head_down
# Processing asitwas_jump at frame 3814...
# Processing asitwas_jump at frame 3823...
# Processing asitwas_jump at frame 3832...
# ✔ Saved 3 frames for asitwas_jump
# Processing asitwas_knee at frame 3875...
# Processing asitwas_knee at frame 3883...
# Processing asitwas_knee at frame 3892...
# ✔ Saved 3 frames for asitwas_knee
# Processing asitwas_hi at frame 3892...
# Processing asitwas_hi at frame 3900...
# Processing asitwas_hi at frame 3909...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 3926...
# Processing asitwas_hi at frame 3935...
# Processing asitwas_hi at frame 3944...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_drum at frame 3961...
# Processing asitwas_drum at frame 3969...
# Processing asitwas_drum at frame 3978...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3978...
# Processing asitwas_drum at frame 3987...
# Processing asitwas_drum at frame 3995...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 3995...
# Processing asitwas_drum at frame 4004...
# Processing asitwas_drum at frame 4013...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4012...
# Processing asitwas_drum at frame 4021...
# Processing asitwas_drum at frame 4030...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_hi at frame 4030...
# Processing asitwas_hi at frame 4038...
# Processing asitwas_hi at frame 4047...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 4064...
# Processing asitwas_hi at frame 4073...
# Processing asitwas_hi at frame 4082...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_drum at frame 4099...
# Processing asitwas_drum at frame 4107...
# Processing asitwas_drum at frame 4116...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4116...
# Processing asitwas_drum at frame 4125...
# Processing asitwas_drum at frame 4133...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4133...
# Processing asitwas_drum at frame 4142...
# Processing asitwas_drum at frame 4151...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4150...
# Processing asitwas_drum at frame 4159...
# Processing asitwas_drum at frame 4168...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_hi at frame 4168...
# Processing asitwas_hi at frame 4176...
# Processing asitwas_hi at frame 4185...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_hi at frame 4202...
# Processing asitwas_hi at frame 4211...
# Processing asitwas_hi at frame 4219...
# ✔ Saved 3 frames for asitwas_hi
# Processing asitwas_drum at frame 4237...
# Processing asitwas_drum at frame 4245...
# Processing asitwas_drum at frame 4254...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4254...
# Processing asitwas_drum at frame 4263...
# Processing asitwas_drum at frame 4271...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4271...
# Processing asitwas_drum at frame 4280...
# Processing asitwas_drum at frame 4288...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_drum at frame 4288...
# Processing asitwas_drum at frame 4297...
# Processing asitwas_drum at frame 4306...
# ✔ Saved 3 frames for asitwas_drum
# Processing asitwas_arms_open at frame 4306...
# Processing asitwas_arms_open at frame 4314...
# Processing asitwas_arms_open at frame 4323...
# ✔ Saved 3 frames for asitwas_arms_open
# Processing asitwas_arms_close at frame 4344...
# Processing asitwas_arms_close at frame 4353...
# Processing asitwas_arms_close at frame 4362...
# ✔ Saved 3 frames for asitwas_arms_close
# Processing asitwas_final_pose at frame 4362...
# Processing asitwas_final_pose at frame 4370...
# Processing asitwas_final_pose at frame 4379...
# ✔ Saved 3 frames for asitwas_final_pose
# ✅ Reference data saved to reference_moves_three/reference_data.pkl

# %%
import pandas as pd
pd.Series(list(reference_data.keys())).value_counts().max()
# Out:
# 1

# %%
## Draw 1 Frame ##

import cv2
import json
import os
import joblib
import numpy as np

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

# Extract moves
moves = timeline_data["moves"]

# Load reference data
reference_data = joblib.load("reference_moves/reference_data.pkl")

# Load the dance video
video_path = "videoplayback_25fps.mp4"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

# Define colors
WHITE = (255, 255, 255)
RED = (0, 0, 255)
GREEN = (0, 255, 0)
BLUE = (255, 0, 0)

# Joint connections based on the MediaPipe pose model
connections = [
    ("left_shoulder", "right_shoulder"),
    ("left_shoulder", "left_elbow"), ("left_elbow", "left_wrist"),
    ("right_shoulder", "right_elbow"), ("right_elbow", "right_wrist"),
    ("left_shoulder", "left_hip"), ("right_shoulder", "right_hip"),
    ("left_hip", "right_hip")
]

def draw_landmarks(frame, joints):
    """Draws landmarks and connections on the frame."""
    height, width, _ = frame.shape

    # Convert normalized joint coordinates to pixel values
    joint_positions = {key: (int(x * width), int(y * height)) for key, (x, y, z) in joints.items()}

    # Draw connections
    for joint1, joint2 in connections:
        if joint1 in joint_positions and joint2 in joint_positions:
            cv2.line(frame, joint_positions[joint1], joint_positions[joint2], BLUE, 2)

    # Draw joints
    for joint, (x, y) in joint_positions.items():
        cv2.circle(frame, (x, y), 5, RED, -1)

    return frame

# Process each move
for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 2.1 # + 14.828
    duration = move["duration"]

    # Get the corresponding reference data
    if move_name not in reference_data:
        print(f"❌ No reference data found for {move_name}, skipping...")
        continue

    mid_time = start_time + (duration / 2)  # Middle of the move
    frame_idx = int(mid_time * fps)  # Convert to frame index

    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # Seek to the frame
    ret, frame = cap.read()
    
    if not ret:
        print(f"❌ Failed to capture frame for {move_name} at frame {frame_idx}!")
        continue

    print(f"🎨 Drawing landmarks for {move_name} at frame {frame_idx}...")

    joints = reference_data[move_name]["joints"]

    # Draw landmarks
    frame = draw_landmarks(frame, joints)

    # Display the frame
    cv2.imshow("Pose Landmarks", frame)
    key = cv2.waitKey(3000)  # Display for 500ms

    # Press 'q' to exit early
    if key == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Video FPS: 25.0
# 🎨 Drawing landmarks for asitwas_jacket at frame 177...
# 🎨 Drawing landmarks for asitwas_snap at frame 194...
# 🎨 Drawing landmarks for asitwas_arm_up at frame 214...
# 🎨 Drawing landmarks for asitwas_snap_down_start at frame 272...
# 🎨 Drawing landmarks for asitwas_snap_down at frame 289...
# 🎨 Drawing landmarks for asitwas_snap_down at frame 306...
# 🎨 Drawing landmarks for asitwas_snap_down at frame 324...
# 🎨 Drawing landmarks for asitwas_snap_down_start_2 at frame 341...
# 🎨 Drawing landmarks for asitwas_snap_down at frame 358...
# 🎨 Drawing landmarks for asitwas_snap_down at frame 375...

# %%
## Draw 3 Frames ##

import cv2
import json
import os
import joblib
import numpy as np

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

# Extract moves
moves = timeline_data["moves"]

# Load reference data
reference_data = joblib.load("reference_moves_three/reference_data.pkl")

# Load the dance video
video_path = "videoplayback_25fps.mp4"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

# Define colors
WHITE = (255, 255, 255)
RED = (0, 0, 255)
GREEN = (0, 255, 0)
BLUE = (255, 0, 0)

# Joint connections based on the MediaPipe pose model
connections = [
    ("left_shoulder", "right_shoulder"),
    ("left_shoulder", "left_elbow"), ("left_elbow", "left_wrist"),
    ("right_shoulder", "right_elbow"), ("right_elbow", "right_wrist"),
    ("left_shoulder", "left_hip"), ("right_shoulder", "right_hip"),
    ("left_hip", "right_hip")
]

def draw_landmarks(frame, joints):
    """Draws landmarks and connections on the frame."""
    height, width, _ = frame.shape

    # Convert normalized joint coordinates to pixel values
    joint_positions = {key: (int(x * width), int(y * height)) for key, (x, y, z) in joints.items()}

    # Draw connections
    for joint1, joint2 in connections:
        if joint1 in joint_positions and joint2 in joint_positions:
            cv2.line(frame, joint_positions[joint1], joint_positions[joint2], BLUE, 2)

    # Draw joints
    for joint, (x, y) in joint_positions.items():
        cv2.circle(frame, (x, y), 5, RED, -1)

    return frame

# Process each move
for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 2.1
    duration = move["duration"]

    # Get the corresponding reference data
    if move_name not in reference_data or len(reference_data[move_name]) < 3:
        print(f"❌ No reference data found for {move_name}, skipping...")
        continue

    frame_times = [
        start_time + (duration * 0.25),  # First quarter
        start_time + (duration * 0.5),   # Midpoint
        start_time + (duration * 0.75)   # Three-quarters
    ]
    frame_indices = [int(t * fps) for t in frame_times]  # Convert times to frame indices

    for i, frame_idx in enumerate(frame_indices):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # Seek to the frame
        ret, frame = cap.read()
        
        if not ret:
            print(f"❌ Failed to capture frame {i+1} for {move_name} at frame {frame_idx}!")
            continue

        print(f"🎨 Drawing landmarks for {move_name} (Frame {i+1}) at frame {frame_idx}...")

        joints = reference_data[move_name][i]["joints"]  # Get the corresponding pose data

        # Draw landmarks
        frame = draw_landmarks(frame, joints)

        # Display the frame
        cv2.imshow("Pose Landmarks", frame)
        key = cv2.waitKey(1000)  # Display each frame for 1 second

        # Press 'q' to exit early
        if key == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Video FPS: 25.0
# 🎨 Drawing landmarks for asitwas_jacket (Frame 1) at frame 173...
# 🎨 Drawing landmarks for asitwas_jacket (Frame 2) at frame 177...
# 🎨 Drawing landmarks for asitwas_jacket (Frame 3) at frame 181...
# 🎨 Drawing landmarks for asitwas_snap (Frame 1) at frame 190...
# 🎨 Drawing landmarks for asitwas_snap (Frame 2) at frame 194...
# 🎨 Drawing landmarks for asitwas_snap (Frame 3) at frame 199...
# 🎨 Drawing landmarks for asitwas_arm_up (Frame 1) at frame 208...
# 🎨 Drawing landmarks for asitwas_arm_up (Frame 2) at frame 214...
# 🎨 Drawing landmarks for asitwas_arm_up (Frame 3) at frame 219...
# 🎨 Drawing landmarks for asitwas_snap_down_start (Frame 1) at frame 268...
# 🎨 Drawing landmarks for asitwas_snap_down_start (Frame 2) at frame 272...
# 🎨 Drawing landmarks for asitwas_snap_down_start (Frame 3) at frame 276...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 1) at frame 285...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 2) at frame 289...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 3) at frame 293...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 1) at frame 302...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 2) at frame 306...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 1) at frame 319...
# 🎨 Drawing landmarks for asitwas_snap_down_start_2 (Frame 1) at frame 337...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 1) at frame 354...
# 🎨 Drawing landmarks for asitwas_snap_down (Frame 1) at frame 371...
# 🎨 Drawing landmarks for asitwas_snap_down_end (Frame 1) at frame 388...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 405...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 423...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 440...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 474...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 492...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 509...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 543...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 578...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 612...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 647...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 681...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 699...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 716...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 750...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 768...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 785...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 819...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 854...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 888...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 923...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 957...
# 🎨 Drawing landmarks for asitwas_arm_fall (Frame 1) at frame 974...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 991...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 1004...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 1018...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 1035...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 1060...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 1073...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 1087...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 1104...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 1129...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 1141...
# 🎨 Drawing landmarks for asitwas_hips (Frame 1) at frame 1155...
# 🎨 Drawing landmarks for asitwas_hips_2 (Frame 1) at frame 1173...
# 🎨 Drawing landmarks for asitwas_snap_chorus (Frame 1) at frame 1194...
# 🎨 Drawing landmarks for asitwas_snap_chorus_2 (Frame 1) at frame 1212...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 1233...
# 🎨 Drawing landmarks for asitwas_arm_fall (Frame 1) at frame 1250...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 1266...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 1279...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 1293...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 1311...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 1335...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 1348...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 1362...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 1380...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 1404...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 1417...
# 🎨 Drawing landmarks for asitwas_hips (Frame 1) at frame 1431...
# 🎨 Drawing landmarks for asitwas_hips_2 (Frame 1) at frame 1449...
# 🎨 Drawing landmarks for asitwas_snap_chorus (Frame 1) at frame 1470...
# 🎨 Drawing landmarks for asitwas_snap_chorus_2 (Frame 1) at frame 1487...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1509...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1526...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1543...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1561...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 1578...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 1612...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1647...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1664...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1681...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 1699...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 1716...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 1750...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 1785...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 1802...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 1819...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 1854...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 1871...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 1888...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 1923...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 1957...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 1992...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 2026...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 2061...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 2078...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 2095...
# 🎨 Drawing landmarks for asitwas_arm_down (Frame 1) at frame 2130...
# 🎨 Drawing landmarks for asitwas_sun (Frame 1) at frame 2147...
# 🎨 Drawing landmarks for asitwas_fists (Frame 1) at frame 2164...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 2199...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 2233...
# 🎨 Drawing landmarks for asitwas_circle (Frame 1) at frame 2268...
# 🎨 Drawing landmarks for asitwas_circle_2 (Frame 1) at frame 2302...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 2337...
# 🎨 Drawing landmarks for asitwas_arm_fall (Frame 1) at frame 2354...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 2370...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 2383...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 2397...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 2414...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 2439...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 2452...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 2466...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 2483...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 2508...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 2521...
# 🎨 Drawing landmarks for asitwas_hips (Frame 1) at frame 2535...
# 🎨 Drawing landmarks for asitwas_hips_2 (Frame 1) at frame 2552...
# 🎨 Drawing landmarks for asitwas_snap_chorus (Frame 1) at frame 2574...
# 🎨 Drawing landmarks for asitwas_snap_chorus_2 (Frame 1) at frame 2591...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 2612...
# 🎨 Drawing landmarks for asitwas_arm_fall (Frame 1) at frame 2630...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 2646...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 2659...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 2673...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 2690...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 2715...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 2728...
# 🎨 Drawing landmarks for asitwas_cross_arm (Frame 1) at frame 2742...
# 🎨 Drawing landmarks for asitwas_arm_fall_2 (Frame 1) at frame 2759...
# 🎨 Drawing landmarks for asitwas_belly (Frame 1) at frame 2784...
# 🎨 Drawing landmarks for asitwas_belly_2 (Frame 1) at frame 2797...
# 🎨 Drawing landmarks for asitwas_hips (Frame 1) at frame 2811...
# 🎨 Drawing landmarks for asitwas_hips_2 (Frame 1) at frame 2828...
# 🎨 Drawing landmarks for asitwas_snap_chorus (Frame 1) at frame 2849...
# 🎨 Drawing landmarks for asitwas_snap_chorus_2 (Frame 1) at frame 2867...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 2888...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 2905...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 2923...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 2940...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 2957...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 2992...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3026...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3043...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3061...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3078...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3095...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3130...
# 🎨 Drawing landmarks for asitwas_run (Frame 1) at frame 3164...
# 🎨 Drawing landmarks for asitwas_hair (Frame 1) at frame 3181...
# 🎨 Drawing landmarks for asitwas_run (Frame 1) at frame 3199...
# 🎨 Drawing landmarks for asitwas_hair (Frame 1) at frame 3216...
# 🎨 Drawing landmarks for asitwas_jacket_2_start (Frame 1) at frame 3233...
# 🎨 Drawing landmarks for asitwas_jacket_2 (Frame 1) at frame 3250...
# 🎨 Drawing landmarks for asitwas_jacket_2 (Frame 1) at frame 3268...
# 🎨 Drawing landmarks for asitwas_jacket_2 (Frame 1) at frame 3285...
# 🎨 Drawing landmarks for asitwas_run (Frame 1) at frame 3302...
# 🎨 Drawing landmarks for asitwas_hair (Frame 1) at frame 3319...
# 🎨 Drawing landmarks for asitwas_run (Frame 1) at frame 3337...
# 🎨 Drawing landmarks for asitwas_hair (Frame 1) at frame 3354...
# 🎨 Drawing landmarks for asitwas_jacket_2_start (Frame 1) at frame 3371...
# 🎨 Drawing landmarks for asitwas_jacket_2 (Frame 1) at frame 3388...
# 🎨 Drawing landmarks for asitwas_jacket_2 (Frame 1) at frame 3405...
# 🎨 Drawing landmarks for asitwas_jacket_end (Frame 1) at frame 3423...
# 🎨 Drawing landmarks for asitwas_hands (Frame 1) at frame 3440...
# 🎨 Drawing landmarks for asitwas_hands_2 (Frame 1) at frame 3457...
# 🎨 Drawing landmarks for asitwas_head_down (Frame 1) at frame 3483...
# 🎨 Drawing landmarks for asitwas_jump (Frame 1) at frame 3500...
# 🎨 Drawing landmarks for asitwas_knee (Frame 1) at frame 3561...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3578...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3612...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3647...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3664...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3681...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3699...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3716...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3750...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3785...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3802...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3819...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3837...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3854...
# 🎨 Drawing landmarks for asitwas_hi (Frame 1) at frame 3888...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3923...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3940...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3957...
# 🎨 Drawing landmarks for asitwas_drum (Frame 1) at frame 3974...
# 🎨 Drawing landmarks for asitwas_arms_open (Frame 1) at frame 3992...
# 🎨 Drawing landmarks for asitwas_arms_close (Frame 1) at frame 4030...
# 🎨 Drawing landmarks for asitwas_final_pose (Frame 1) at frame 4048...

# %%
## Score 1 Frame ##

import cv2
import mediapipe as mp
import json
import numpy as np
import joblib

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

moves = timeline_data["moves"]  # Extract move data

# Load reference move data
reference_data = joblib.load("reference_moves/reference_data.pkl")

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose()

# Load the dance video
video_path = "videoplayback_25fps.mp4"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

def calculate_angle(a, b, c):
    """Calculate angle between three 3D points using the arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))

    return np.degrees(angle)

def process_frame(image):
    """Extract pose landmarks and compute angles from a frame."""
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Joint indices for key body parts
        joint_ids = {
            "nose": 0,
            "left_shoulder": 11, "right_shoulder": 12,
            "left_elbow": 13, "right_elbow": 14,
            "left_wrist": 15, "right_wrist": 16,
            "left_hip": 23, "right_hip": 24
        }

        joints = {name: (landmarks[idx].x, landmarks[idx].y, landmarks[idx].z) for name, idx in joint_ids.items()}

        # Compute angles
        angles = {}

        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["left_elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["right_shoulder", "right_elbow", "right_wrist"]):
            angles["right_elbow"] = calculate_angle(joints["right_shoulder"], joints["right_elbow"], joints["right_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_hip"]):
            angles["left_arm_lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_hip"])
        if all(k in joints for k in ["right_elbow", "right_shoulder", "right_hip"]):
            angles["right_arm_lift"] = calculate_angle(joints["right_elbow"], joints["right_shoulder"], joints["right_hip"])

        return {"joints": joints, "angles": angles}

    return None

def score_angles(reference_angles, detected_angles):
    """Compare angles with reference and return a score."""
    total_score = 0
    count = 0

    for key in reference_angles:
        if key in detected_angles:
            diff = abs(reference_angles[key] - detected_angles[key])

            if diff < 20:
                score = 100  # Perfect
            elif diff < 30:
                score = 70  # Okay
            else:
                score = 40  # Bad

            total_score += score
            count += 1

    return total_score / count if count > 0 else 0  # Average score

# Initialize final accuracy tracking
total_moves = 0
total_accuracy = 0

# Process each move in the timeline
for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 2.1 # + 14.828
    duration = move["duration"]

    mid_time = start_time + (duration / 2)  # Middle of the move
    frame_idx = int(mid_time * fps)  # Convert to frame index
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # Seek to the frame

    ret, frame = cap.read()
    if not ret:
        print(f"Failed to capture frame for {move_name} at time {mid_time}s (frame {frame_idx})!")
        continue

    print(f"Processing {move_name} at frame {frame_idx}...")

    detected_pose = process_frame(frame)
    if not detected_pose:
        print(f"❌ No pose detected for {move_name}")
        continue

    # Get reference pose angles
    if move_name in reference_data:
        reference_angles = reference_data[move_name]["angles"]
    else:
        print(f"❌ No reference data for {move_name}")
        continue

    # Score the move
    score = score_angles(reference_angles, detected_pose["angles"])
    total_moves += 1
    total_accuracy += score

    # Draw landmarks and score on the frame
    mp_drawing.draw_landmarks(frame, pose.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).pose_landmarks, mp_pose.POSE_CONNECTIONS)

    # Display move name and score on frame
    cv2.putText(frame, f"Move: {move_name}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    cv2.putText(frame, f"Score: {int(score)}", (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

    cv2.imshow(f"Dance Scoring", frame)
    key = cv2.waitKey(500)  # Display for 500ms

    # Press 'q' to exit early
    if key == ord('q'):
        break


# Print final accuracy
if total_moves > 0:
    final_accuracy = total_accuracy / total_moves
    print(f"\n✅ Final Accuracy: {final_accuracy:.2f}%")
else:
    print("\n❌ No valid moves were detected.")

cv2.destroyAllWindows()
cap.release()
# Out:
# Video FPS: 25.0
# Processing asitwas_jacket at frame 177...
# Processing asitwas_snap at frame 194...
# Processing asitwas_arm_up at frame 214...
# Processing asitwas_snap_down_start at frame 272...
# Processing asitwas_snap_down at frame 289...
# Processing asitwas_snap_down at frame 306...
# Processing asitwas_snap_down at frame 324...
# Processing asitwas_snap_down_start_2 at frame 341...
# Processing asitwas_snap_down at frame 358...
# Processing asitwas_snap_down at frame 375...
# Processing asitwas_snap_down_end at frame 393...
# Processing asitwas_arm_down at frame 410...
# Processing asitwas_sun at frame 427...
# Processing asitwas_fists at frame 444...
# Processing asitwas_arm_down at frame 479...
# Processing asitwas_sun at frame 496...
# Processing asitwas_fists at frame 513...
# Processing asitwas_circle at frame 548...
# Processing asitwas_circle_2 at frame 582...
# Processing asitwas_circle at frame 617...
# Processing asitwas_circle_2 at frame 651...
# Processing asitwas_arm_down at frame 686...
# Processing asitwas_sun at frame 703...
# Processing asitwas_fists at frame 720...
# Processing asitwas_arm_down at frame 755...
# Processing asitwas_sun at frame 772...
# Processing asitwas_fists at frame 789...
# Processing asitwas_circle at frame 824...
# Processing asitwas_circle_2 at frame 858...
# Processing asitwas_circle at frame 893...
# Processing asitwas_circle_2 at frame 927...
# Processing asitwas_cross_arm at frame 962...
# Processing asitwas_arm_fall at frame 979...
# Processing asitwas_belly at frame 994...
# Processing asitwas_belly_2 at frame 1007...
# Processing asitwas_cross_arm at frame 1022...
# Processing asitwas_arm_fall_2 at frame 1039...
# Processing asitwas_belly at frame 1063...
# Processing asitwas_belly_2 at frame 1076...
# Processing asitwas_cross_arm at frame 1091...
# Processing asitwas_arm_fall_2 at frame 1108...
# Processing asitwas_belly at frame 1132...
# Processing asitwas_belly_2 at frame 1145...
# Processing asitwas_hips at frame 1160...
# Processing asitwas_hips_2 at frame 1177...
# Processing asitwas_snap_chorus at frame 1199...
# Processing asitwas_snap_chorus_2 at frame 1216...
# Processing asitwas_cross_arm at frame 1237...
# Processing asitwas_arm_fall at frame 1255...
# Processing asitwas_belly at frame 1270...
# Processing asitwas_belly_2 at frame 1283...
# Processing asitwas_cross_arm at frame 1298...
# Processing asitwas_arm_fall_2 at frame 1315...
# Processing asitwas_belly at frame 1339...
# Processing asitwas_belly_2 at frame 1352...
# Processing asitwas_cross_arm at frame 1367...
# Processing asitwas_arm_fall_2 at frame 1384...
# Processing asitwas_belly at frame 1408...
# Processing asitwas_belly_2 at frame 1421...
# Processing asitwas_hips at frame 1436...
# Processing asitwas_hips_2 at frame 1453...
# Processing asitwas_snap_chorus at frame 1474...
# Processing asitwas_snap_chorus_2 at frame 1492...
# Processing asitwas_drum at frame 1513...
# Processing asitwas_drum at frame 1531...
# Processing asitwas_drum at frame 1548...
# Processing asitwas_drum at frame 1565...
# Processing asitwas_hi at frame 1582...
# Processing asitwas_hi at frame 1617...
# Processing asitwas_drum at frame 1651...
# Processing asitwas_drum at frame 1668...
# Processing asitwas_drum at frame 1686...
# Processing asitwas_drum at frame 1703...
# Processing asitwas_hi at frame 1720...
# Processing asitwas_hi at frame 1755...
# Processing asitwas_arm_down at frame 1789...
# Processing asitwas_sun at frame 1806...
# Processing asitwas_fists at frame 1824...
# Processing asitwas_arm_down at frame 1858...
# Processing asitwas_sun at frame 1875...
# Processing asitwas_fists at frame 1893...
# Processing asitwas_circle at frame 1927...
# Processing asitwas_circle_2 at frame 1962...
# Processing asitwas_circle at frame 1996...
# Processing asitwas_circle_2 at frame 2031...
# Processing asitwas_arm_down at frame 2065...
# Processing asitwas_sun at frame 2082...
# Processing asitwas_fists at frame 2099...
# Processing asitwas_arm_down at frame 2134...
# Processing asitwas_sun at frame 2151...
# Processing asitwas_fists at frame 2168...
# Processing asitwas_circle at frame 2203...
# Processing asitwas_circle_2 at frame 2237...
# Processing asitwas_circle at frame 2272...
# Processing asitwas_circle_2 at frame 2306...
# Processing asitwas_cross_arm at frame 2341...
# Processing asitwas_arm_fall at frame 2358...
# Processing asitwas_belly at frame 2373...
# Processing asitwas_belly_2 at frame 2386...
# Processing asitwas_cross_arm at frame 2401...
# Processing asitwas_arm_fall_2 at frame 2418...
# Processing asitwas_belly at frame 2442...
# Processing asitwas_belly_2 at frame 2455...
# Processing asitwas_cross_arm at frame 2470...
# Processing asitwas_arm_fall_2 at frame 2487...
# Processing asitwas_belly at frame 2511...
# Processing asitwas_belly_2 at frame 2524...
# Processing asitwas_hips at frame 2539...
# Processing asitwas_hips_2 at frame 2556...
# Processing asitwas_snap_chorus at frame 2578...
# Processing asitwas_snap_chorus_2 at frame 2595...
# Processing asitwas_cross_arm at frame 2617...
# Processing asitwas_arm_fall at frame 2634...
# Processing asitwas_belly at frame 2649...
# Processing asitwas_belly_2 at frame 2662...
# Processing asitwas_cross_arm at frame 2677...
# Processing asitwas_arm_fall_2 at frame 2694...
# Processing asitwas_belly at frame 2718...
# Processing asitwas_belly_2 at frame 2731...
# Processing asitwas_cross_arm at frame 2746...
# Processing asitwas_arm_fall_2 at frame 2763...
# Processing asitwas_belly at frame 2787...
# Processing asitwas_belly_2 at frame 2800...
# Processing asitwas_hips at frame 2815...
# Processing asitwas_hips_2 at frame 2832...
# Processing asitwas_snap_chorus at frame 2854...
# Processing asitwas_snap_chorus_2 at frame 2871...
# Processing asitwas_drum at frame 2893...
# Processing asitwas_drum at frame 2910...
# Processing asitwas_drum at frame 2927...
# Processing asitwas_drum at frame 2944...
# Processing asitwas_hi at frame 2962...
# Processing asitwas_hi at frame 2996...
# Processing asitwas_drum at frame 3031...
# Processing asitwas_drum at frame 3048...
# Processing asitwas_drum at frame 3065...
# Processing asitwas_drum at frame 3082...
# Processing asitwas_hi at frame 3099...
# Processing asitwas_hi at frame 3134...
# Processing asitwas_run at frame 3168...
# Processing asitwas_hair at frame 3186...
# Processing asitwas_run at frame 3203...
# Processing asitwas_hair at frame 3220...
# ❌ No pose detected for asitwas_hair
# Processing asitwas_jacket_2_start at frame 3237...
# Processing asitwas_jacket_2 at frame 3255...
# Processing asitwas_jacket_2 at frame 3272...
# Processing asitwas_jacket_2 at frame 3289...
# Processing asitwas_run at frame 3306...
# Processing asitwas_hair at frame 3324...
# Processing asitwas_run at frame 3341...
# Processing asitwas_hair at frame 3358...
# Processing asitwas_jacket_2_start at frame 3375...
# Processing asitwas_jacket_2 at frame 3393...
# Processing asitwas_jacket_2 at frame 3410...
# Processing asitwas_jacket_end at frame 3427...
# Processing asitwas_hands at frame 3444...
# Processing asitwas_hands_2 at frame 3462...
# Processing asitwas_head_down at frame 3487...
# Processing asitwas_jump at frame 3505...
# Processing asitwas_knee at frame 3565...
# Processing asitwas_hi at frame 3582...
# Processing asitwas_hi at frame 3617...
# Processing asitwas_drum at frame 3651...
# Processing asitwas_drum at frame 3668...
# Processing asitwas_drum at frame 3686...
# Processing asitwas_drum at frame 3703...
# Processing asitwas_hi at frame 3720...
# Processing asitwas_hi at frame 3755...
# Processing asitwas_drum at frame 3789...
# Processing asitwas_drum at frame 3806...
# Processing asitwas_drum at frame 3824...
# Processing asitwas_drum at frame 3841...
# Processing asitwas_hi at frame 3858...
# Processing asitwas_hi at frame 3893...
# Processing asitwas_drum at frame 3927...
# Processing asitwas_drum at frame 3944...
# Processing asitwas_drum at frame 3962...
# Processing asitwas_drum at frame 3979...
# Processing asitwas_arms_open at frame 3996...
# Processing asitwas_arms_close at frame 4035...
# Processing asitwas_final_pose at frame 4052...
#
# ✅ Final Accuracy: 74.54%

# %%
## Score 3 Frames without drawing ref ##

import cv2
import mediapipe as mp
import json
import numpy as np
import joblib

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

moves = timeline_data["moves"]  # Extract move data

# Load reference move data
reference_data = joblib.load("reference_moves_three/reference_data.pkl")

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose()

# Load the dance video
video_path = "videoplayback_25fps.mp4"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

def calculate_angle(a, b, c):
    """Calculate angle between three 3D points using the arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))

    return np.degrees(angle)

def process_frame(image):
    """Extract pose landmarks and compute angles from a frame."""
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Joint indices for key body parts
        joint_ids = {
            "nose": 0,
            "left_shoulder": 11, "right_shoulder": 12,
            "left_elbow": 13, "right_elbow": 14,
            "left_wrist": 15, "right_wrist": 16,
            "left_hip": 23, "right_hip": 24
        }

        joints = {name: (landmarks[idx].x, landmarks[idx].y, landmarks[idx].z) for name, idx in joint_ids.items()}

        # Compute angles
        angles = {}

        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["left_elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["right_shoulder", "right_elbow", "right_wrist"]):
            angles["right_elbow"] = calculate_angle(joints["right_shoulder"], joints["right_elbow"], joints["right_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_hip"]):
            angles["left_arm_lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_hip"])
        if all(k in joints for k in ["right_elbow", "right_shoulder", "right_hip"]):
            angles["right_arm_lift"] = calculate_angle(joints["right_elbow"], joints["right_shoulder"], joints["right_hip"])

        return {"joints": joints, "angles": angles}

    return None

def score_angles(reference_angles, detected_angles):
    """Compare angles with reference and return a score."""
    total_score = 0
    count = 0

    for key in reference_angles:
        if key in detected_angles:
            diff = abs(reference_angles[key] - detected_angles[key])

            if diff < 20:
                score = 100  # Perfect
            elif diff < 40:
                score = 70  # Okay
            else:
                score = 40  # Bad

            total_score += score
            count += 1

    return total_score / count if count > 0 else 0  # Average score

# Initialize final accuracy tracking
total_moves = 0
total_accuracy = 0

# Process each move in the timeline
for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 2.1  # Adjust timing offset
    duration = move["duration"]

    # Get the three frame times (25%, 50%, and 75% of move duration)
    frame_times = [
        start_time + (duration * 0.25),  # First quarter
        start_time + (duration * 0.5),   # Midpoint
        start_time + (duration * 0.75)   # Three-quarters
    ]
    frame_indices = [int(t * fps) for t in frame_times]  # Convert times to frame indices

    if move_name not in reference_data or len(reference_data[move_name]) < 3:
        print(f"❌ No reference data found for {move_name}, skipping...")
        continue

    total_move_score = 0  # Sum of scores for the three frames
    valid_frames = 0  # Count of successfully processed frames

    for i, frame_idx in enumerate(frame_indices):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # Seek to the frame
        ret, frame = cap.read()

        if not ret:
            print(f"❌ Failed to capture frame {i+1} for {move_name} at frame {frame_idx}!")
            continue

        print(f"🎨 Processing {move_name} (Frame {i+1}) at frame {frame_idx}...")

        detected_pose = process_frame(frame)
        if not detected_pose:
            print(f"❌ No pose detected for {move_name} (Frame {i+1})")
            continue

        # Get reference pose angles for this frame
        reference_angles = reference_data[move_name][i]["angles"]

        # Score the move
        score = score_angles(reference_angles, detected_pose["angles"])
        total_move_score += score
        valid_frames += 1

        # Draw landmarks and score on the frame
        mp_drawing.draw_landmarks(frame, pose.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).pose_landmarks, mp_pose.POSE_CONNECTIONS)

        # Display move name and score on frame
        cv2.putText(frame, f"Move: {move_name}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
        cv2.putText(frame, f"Score: {int(score)}", (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        cv2.imshow(f"Dance Scoring", frame)
        key = cv2.waitKey(100)  # Display for 1 second

        # Press 'q' to exit early
        if key == ord('q'):
            break

    if valid_frames > 0:
        move_final_score = total_move_score / valid_frames  # Average score across frames
        total_moves += 1
        total_accuracy += move_final_score

        print(f"✅ Final score for {move_name}: {move_final_score:.2f}%\n")

# Print final accuracy
if total_moves > 0:
    final_accuracy = total_accuracy / total_moves
    print(f"\n✅ Final Accuracy: {final_accuracy:.2f}%")
else:
    print("\n❌ No valid moves were detected.")

cv2.destroyAllWindows()
cap.release()
# Out:
# Video FPS: 25.0
# 🎨 Processing asitwas_jacket (Frame 1) at frame 173...
# 🎨 Processing asitwas_jacket (Frame 2) at frame 177...
# 🎨 Processing asitwas_jacket (Frame 3) at frame 181...
# ✅ Final score for asitwas_jacket: 87.50%
#
# 🎨 Processing asitwas_snap (Frame 1) at frame 190...
# 🎨 Processing asitwas_snap (Frame 2) at frame 194...
# 🎨 Processing asitwas_snap (Frame 3) at frame 199...
# ✅ Final score for asitwas_snap: 85.00%
#
# 🎨 Processing asitwas_arm_up (Frame 1) at frame 208...
# 🎨 Processing asitwas_arm_up (Frame 2) at frame 214...
# 🎨 Processing asitwas_arm_up (Frame 3) at frame 219...
# ✅ Final score for asitwas_arm_up: 87.50%
#
# 🎨 Processing asitwas_snap_down_start (Frame 1) at frame 268...
# 🎨 Processing asitwas_snap_down_start (Frame 2) at frame 272...
# 🎨 Processing asitwas_snap_down_start (Frame 3) at frame 276...
# ✅ Final score for asitwas_snap_down_start: 82.50%
#
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 285...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 289...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 293...
# ✅ Final score for asitwas_snap_down: 60.00%
#
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 302...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 306...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 311...
# ✅ Final score for asitwas_snap_down: 70.00%
#
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 319...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 324...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 328...
# ✅ Final score for asitwas_snap_down: 82.50%
#
# 🎨 Processing asitwas_snap_down_start_2 (Frame 1) at frame 337...
# 🎨 Processing asitwas_snap_down_start_2 (Frame 2) at frame 341...
# 🎨 Processing asitwas_snap_down_start_2 (Frame 3) at frame 345...
# ✅ Final score for asitwas_snap_down_start_2: 85.00%
#
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 354...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 358...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 362...
# ✅ Final score for asitwas_snap_down: 75.00%
#
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 371...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 375...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 380...
# ✅ Final score for asitwas_snap_down: 85.00%
#
# 🎨 Processing asitwas_snap_down_end (Frame 1) at frame 388...
# 🎨 Processing asitwas_snap_down_end (Frame 2) at frame 393...
# 🎨 Processing asitwas_snap_down_end (Frame 3) at frame 397...
# ✅ Final score for asitwas_snap_down_end: 80.00%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 405...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 410...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 414...
# ✅ Final score for asitwas_arm_down: 92.50%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 423...
# 🎨 Processing asitwas_sun (Frame 2) at frame 427...
# 🎨 Processing asitwas_sun (Frame 3) at frame 431...
# ✅ Final score for asitwas_sun: 75.00%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 440...
# 🎨 Processing asitwas_fists (Frame 2) at frame 444...
# 🎨 Processing asitwas_fists (Frame 3) at frame 449...
# ✅ Final score for asitwas_fists: 67.50%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 474...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 479...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 483...
# ✅ Final score for asitwas_arm_down: 92.50%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 492...
# 🎨 Processing asitwas_sun (Frame 2) at frame 496...
# 🎨 Processing asitwas_sun (Frame 3) at frame 500...
# ✅ Final score for asitwas_sun: 70.00%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 509...
# 🎨 Processing asitwas_fists (Frame 2) at frame 513...
# 🎨 Processing asitwas_fists (Frame 3) at frame 518...
# ✅ Final score for asitwas_fists: 80.00%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 543...
# 🎨 Processing asitwas_circle (Frame 2) at frame 548...
# 🎨 Processing asitwas_circle (Frame 3) at frame 552...
# ✅ Final score for asitwas_circle: 72.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 578...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 582...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 587...
# ✅ Final score for asitwas_circle_2: 70.00%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 612...
# 🎨 Processing asitwas_circle (Frame 2) at frame 617...
# 🎨 Processing asitwas_circle (Frame 3) at frame 621...
# ✅ Final score for asitwas_circle: 67.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 647...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 651...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 656...
# ✅ Final score for asitwas_circle_2: 70.00%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 681...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 686...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 690...
# ✅ Final score for asitwas_arm_down: 87.50%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 699...
# 🎨 Processing asitwas_sun (Frame 2) at frame 703...
# 🎨 Processing asitwas_sun (Frame 3) at frame 707...
# ✅ Final score for asitwas_sun: 77.50%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 716...
# 🎨 Processing asitwas_fists (Frame 2) at frame 720...
# 🎨 Processing asitwas_fists (Frame 3) at frame 725...
# ✅ Final score for asitwas_fists: 75.00%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 750...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 755...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 759...
# ✅ Final score for asitwas_arm_down: 95.00%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 768...
# 🎨 Processing asitwas_sun (Frame 2) at frame 772...
# 🎨 Processing asitwas_sun (Frame 3) at frame 776...
# ✅ Final score for asitwas_sun: 80.00%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 785...
# 🎨 Processing asitwas_fists (Frame 2) at frame 789...
# 🎨 Processing asitwas_fists (Frame 3) at frame 793...
# ✅ Final score for asitwas_fists: 70.00%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 819...
# 🎨 Processing asitwas_circle (Frame 2) at frame 824...
# 🎨 Processing asitwas_circle (Frame 3) at frame 828...
# ✅ Final score for asitwas_circle: 67.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 854...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 858...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 862...
# ✅ Final score for asitwas_circle_2: 75.00%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 888...
# 🎨 Processing asitwas_circle (Frame 2) at frame 893...
# 🎨 Processing asitwas_circle (Frame 3) at frame 897...
# ✅ Final score for asitwas_circle: 67.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 923...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 927...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 931...
# ✅ Final score for asitwas_circle_2: 75.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 957...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 962...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 966...
# ✅ Final score for asitwas_cross_arm: 62.50%
#
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 974...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 979...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 983...
# ✅ Final score for asitwas_arm_fall: 77.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 991...
# 🎨 Processing asitwas_belly (Frame 2) at frame 994...
# 🎨 Processing asitwas_belly (Frame 3) at frame 997...
# ✅ Final score for asitwas_belly: 85.00%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1004...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1007...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1010...
# ✅ Final score for asitwas_belly_2: 92.50%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1018...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1022...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1026...
# ✅ Final score for asitwas_cross_arm: 65.00%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1035...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1039...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1043...
# ✅ Final score for asitwas_arm_fall_2: 72.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 1060...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1063...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1066...
# ✅ Final score for asitwas_belly: 85.00%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1073...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1076...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1079...
# ✅ Final score for asitwas_belly_2: 95.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1087...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1091...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1095...
# ✅ Final score for asitwas_cross_arm: 62.50%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1104...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1108...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1112...
# ✅ Final score for asitwas_arm_fall_2: 65.00%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 1129...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1132...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1135...
# ✅ Final score for asitwas_belly: 85.00%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1141...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1145...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1148...
# ✅ Final score for asitwas_belly_2: 85.00%
#
# 🎨 Processing asitwas_hips (Frame 1) at frame 1155...
# 🎨 Processing asitwas_hips (Frame 2) at frame 1160...
# 🎨 Processing asitwas_hips (Frame 3) at frame 1164...
# ✅ Final score for asitwas_hips: 82.50%
#
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 1173...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 1177...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 1181...
# ✅ Final score for asitwas_hips_2: 85.00%
#
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 1194...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 1199...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 1203...
# ✅ Final score for asitwas_snap_chorus: 80.00%
#
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 1212...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 1216...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 1220...
# ✅ Final score for asitwas_snap_chorus_2: 77.50%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1233...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1237...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1242...
# ✅ Final score for asitwas_cross_arm: 70.00%
#
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 1250...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 1255...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 1259...
# ✅ Final score for asitwas_arm_fall: 77.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 1266...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1270...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1273...
# ✅ Final score for asitwas_belly: 77.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1279...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1283...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1286...
# ✅ Final score for asitwas_belly_2: 85.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1293...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1298...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1302...
# ✅ Final score for asitwas_cross_arm: 75.00%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1311...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1315...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1319...
# ✅ Final score for asitwas_arm_fall_2: 67.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 1335...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1339...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1342...
# ✅ Final score for asitwas_belly: 87.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1348...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1352...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1355...
# ✅ Final score for asitwas_belly_2: 87.50%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1362...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1367...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1371...
# ✅ Final score for asitwas_cross_arm: 87.50%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1380...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1384...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1388...
# ✅ Final score for asitwas_arm_fall_2: 70.00%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 1404...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1408...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1411...
# ✅ Final score for asitwas_belly: 85.00%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1417...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1421...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1424...
# ✅ Final score for asitwas_belly_2: 90.00%
#
# 🎨 Processing asitwas_hips (Frame 1) at frame 1431...
# 🎨 Processing asitwas_hips (Frame 2) at frame 1436...
# 🎨 Processing asitwas_hips (Frame 3) at frame 1440...
# ✅ Final score for asitwas_hips: 85.00%
#
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 1449...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 1453...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 1457...
# ✅ Final score for asitwas_hips_2: 77.50%
#
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 1470...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 1474...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 1479...
# ✅ Final score for asitwas_snap_chorus: 82.50%
#
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 1487...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 1492...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 1496...
# ✅ Final score for asitwas_snap_chorus_2: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1509...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1513...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1518...
# ✅ Final score for asitwas_drum: 87.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1526...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1531...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1535...
# ✅ Final score for asitwas_drum: 92.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1543...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1548...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1552...
# ✅ Final score for asitwas_drum: 87.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1561...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1565...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1569...
# ✅ Final score for asitwas_drum: 75.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 1578...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1582...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1587...
# ✅ Final score for asitwas_hi: 77.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 1612...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1617...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1621...
# ✅ Final score for asitwas_hi: 82.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1647...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1651...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1656...
# ✅ Final score for asitwas_drum: 92.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1664...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1668...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1673...
# ✅ Final score for asitwas_drum: 75.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1681...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1686...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1690...
# ✅ Final score for asitwas_drum: 87.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 1699...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1703...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1707...
# ✅ Final score for asitwas_drum: 72.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 1716...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1720...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1725...
# ✅ Final score for asitwas_hi: 75.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 1750...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1755...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1759...
# ✅ Final score for asitwas_hi: 77.50%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 1785...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 1789...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 1793...
# ✅ Final score for asitwas_arm_down: 85.00%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 1802...
# 🎨 Processing asitwas_sun (Frame 2) at frame 1806...
# 🎨 Processing asitwas_sun (Frame 3) at frame 1811...
# ✅ Final score for asitwas_sun: 75.00%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 1819...
# 🎨 Processing asitwas_fists (Frame 2) at frame 1824...
# 🎨 Processing asitwas_fists (Frame 3) at frame 1828...
# ✅ Final score for asitwas_fists: 72.50%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 1854...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 1858...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 1862...
# ✅ Final score for asitwas_arm_down: 92.50%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 1871...
# 🎨 Processing asitwas_sun (Frame 2) at frame 1875...
# 🎨 Processing asitwas_sun (Frame 3) at frame 1880...
# ✅ Final score for asitwas_sun: 72.50%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 1888...
# 🎨 Processing asitwas_fists (Frame 2) at frame 1893...
# 🎨 Processing asitwas_fists (Frame 3) at frame 1897...
# ✅ Final score for asitwas_fists: 77.50%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 1923...
# 🎨 Processing asitwas_circle (Frame 2) at frame 1927...
# 🎨 Processing asitwas_circle (Frame 3) at frame 1931...
# ✅ Final score for asitwas_circle: 75.00%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 1957...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 1962...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 1966...
# ✅ Final score for asitwas_circle_2: 70.00%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 1992...
# 🎨 Processing asitwas_circle (Frame 2) at frame 1996...
# 🎨 Processing asitwas_circle (Frame 3) at frame 2000...
# ✅ Final score for asitwas_circle: 77.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 2026...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 2031...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 2035...
# ✅ Final score for asitwas_circle_2: 60.00%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 2061...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 2065...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 2069...
# ✅ Final score for asitwas_arm_down: 90.00%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 2078...
# 🎨 Processing asitwas_sun (Frame 2) at frame 2082...
# 🎨 Processing asitwas_sun (Frame 3) at frame 2087...
# ✅ Final score for asitwas_sun: 72.50%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 2095...
# 🎨 Processing asitwas_fists (Frame 2) at frame 2099...
# 🎨 Processing asitwas_fists (Frame 3) at frame 2104...
# ✅ Final score for asitwas_fists: 70.00%
#
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 2130...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 2134...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 2138...
# ✅ Final score for asitwas_arm_down: 92.50%
#
# 🎨 Processing asitwas_sun (Frame 1) at frame 2147...
# 🎨 Processing asitwas_sun (Frame 2) at frame 2151...
# 🎨 Processing asitwas_sun (Frame 3) at frame 2156...
# ✅ Final score for asitwas_sun: 92.50%
#
# 🎨 Processing asitwas_fists (Frame 1) at frame 2164...
# 🎨 Processing asitwas_fists (Frame 2) at frame 2168...
# 🎨 Processing asitwas_fists (Frame 3) at frame 2173...
# ✅ Final score for asitwas_fists: 75.00%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 2199...
# 🎨 Processing asitwas_circle (Frame 2) at frame 2203...
# 🎨 Processing asitwas_circle (Frame 3) at frame 2207...
# ✅ Final score for asitwas_circle: 77.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 2233...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 2237...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 2242...
# ✅ Final score for asitwas_circle_2: 67.50%
#
# 🎨 Processing asitwas_circle (Frame 1) at frame 2268...
# 🎨 Processing asitwas_circle (Frame 2) at frame 2272...
# 🎨 Processing asitwas_circle (Frame 3) at frame 2276...
# ✅ Final score for asitwas_circle: 67.50%
#
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 2302...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 2306...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 2311...
# ✅ Final score for asitwas_circle_2: 70.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2337...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2341...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2345...
# ✅ Final score for asitwas_cross_arm: 65.00%
#
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 2354...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 2358...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 2362...
# ✅ Final score for asitwas_arm_fall: 82.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 2370...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2373...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2376...
# ✅ Final score for asitwas_belly: 85.00%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2383...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2386...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2389...
# ✅ Final score for asitwas_belly_2: 80.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2397...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2401...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2406...
# ✅ Final score for asitwas_cross_arm: 62.50%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2414...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2418...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2423...
# ✅ Final score for asitwas_arm_fall_2: 67.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 2439...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2442...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2445...
# ✅ Final score for asitwas_belly: 87.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2452...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2455...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2458...
# ✅ Final score for asitwas_belly_2: 80.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2466...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2470...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2475...
# ✅ Final score for asitwas_cross_arm: 65.00%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2483...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2487...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2492...
# ✅ Final score for asitwas_arm_fall_2: 70.00%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 2508...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2511...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2514...
# ✅ Final score for asitwas_belly: 82.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2521...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2524...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2527...
# ✅ Final score for asitwas_belly_2: 82.50%
#
# 🎨 Processing asitwas_hips (Frame 1) at frame 2535...
# 🎨 Processing asitwas_hips (Frame 2) at frame 2539...
# 🎨 Processing asitwas_hips (Frame 3) at frame 2543...
# ✅ Final score for asitwas_hips: 82.50%
#
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 2552...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 2556...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 2561...
# ✅ Final score for asitwas_hips_2: 80.00%
#
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 2574...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 2578...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 2582...
# ✅ Final score for asitwas_snap_chorus: 80.00%
#
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 2591...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 2595...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 2600...
# ✅ Final score for asitwas_snap_chorus_2: 85.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2612...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2617...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2621...
# ✅ Final score for asitwas_cross_arm: 80.00%
#
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 2630...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 2634...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 2638...
# ✅ Final score for asitwas_arm_fall: 67.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 2646...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2649...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2652...
# ✅ Final score for asitwas_belly: 87.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2659...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2662...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2665...
# ✅ Final score for asitwas_belly_2: 85.00%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2673...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2677...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2681...
# ✅ Final score for asitwas_cross_arm: 67.50%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2690...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2694...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2699...
# ✅ Final score for asitwas_arm_fall_2: 67.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 2715...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2718...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2721...
# ✅ Final score for asitwas_belly: 87.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2728...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2731...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2734...
# ✅ Final score for asitwas_belly_2: 92.50%
#
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2742...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2746...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2750...
# ✅ Final score for asitwas_cross_arm: 77.50%
#
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2759...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2763...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2768...
# ✅ Final score for asitwas_arm_fall_2: 62.50%
#
# 🎨 Processing asitwas_belly (Frame 1) at frame 2784...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2787...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2790...
# ✅ Final score for asitwas_belly: 87.50%
#
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2797...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2800...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2803...
# ✅ Final score for asitwas_belly_2: 87.50%
#
# 🎨 Processing asitwas_hips (Frame 1) at frame 2811...
# 🎨 Processing asitwas_hips (Frame 2) at frame 2815...
# 🎨 Processing asitwas_hips (Frame 3) at frame 2819...
# ✅ Final score for asitwas_hips: 92.50%
#
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 2828...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 2832...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 2837...
# ✅ Final score for asitwas_hips_2: 80.00%
#
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 2849...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 2854...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 2858...
# ✅ Final score for asitwas_snap_chorus: 70.00%
#
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 2867...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 2871...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 2875...
# ✅ Final score for asitwas_snap_chorus_2: 87.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 2888...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2893...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2897...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 2905...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2910...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2914...
# ✅ Final score for asitwas_drum: 80.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 2923...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2927...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2931...
# ✅ Final score for asitwas_drum: 75.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 2940...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2944...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2949...
# ✅ Final score for asitwas_drum: 72.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 2957...
# 🎨 Processing asitwas_hi (Frame 2) at frame 2962...
# 🎨 Processing asitwas_hi (Frame 3) at frame 2966...
# ✅ Final score for asitwas_hi: 80.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 2992...
# 🎨 Processing asitwas_hi (Frame 2) at frame 2996...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3000...
# ✅ Final score for asitwas_hi: 77.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3026...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3031...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3035...
# ✅ Final score for asitwas_drum: 92.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3043...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3048...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3052...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3061...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3065...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3069...
# ✅ Final score for asitwas_drum: 90.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3078...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3082...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3087...
# ✅ Final score for asitwas_drum: 82.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3095...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3099...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3104...
# ✅ Final score for asitwas_hi: 72.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3130...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3134...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3138...
# ✅ Final score for asitwas_hi: 77.50%
#
# 🎨 Processing asitwas_run (Frame 1) at frame 3164...
# 🎨 Processing asitwas_run (Frame 2) at frame 3168...
# 🎨 Processing asitwas_run (Frame 3) at frame 3173...
# ✅ Final score for asitwas_run: 65.00%
#
# 🎨 Processing asitwas_hair (Frame 1) at frame 3181...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3186...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3190...
# ✅ Final score for asitwas_hair: 67.50%
#
# 🎨 Processing asitwas_run (Frame 1) at frame 3199...
# 🎨 Processing asitwas_run (Frame 2) at frame 3203...
# 🎨 Processing asitwas_run (Frame 3) at frame 3207...
# ✅ Final score for asitwas_run: 62.50%
#
# 🎨 Processing asitwas_hair (Frame 1) at frame 3216...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3220...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3225...
# ✅ Final score for asitwas_hair: 75.00%
#
# 🎨 Processing asitwas_jacket_2_start (Frame 1) at frame 3233...
# 🎨 Processing asitwas_jacket_2_start (Frame 2) at frame 3237...
# 🎨 Processing asitwas_jacket_2_start (Frame 3) at frame 3242...
# ✅ Final score for asitwas_jacket_2_start: 90.00%
#
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3250...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3255...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3259...
# ✅ Final score for asitwas_jacket_2: 65.00%
#
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3268...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3272...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3276...
# ✅ Final score for asitwas_jacket_2: 85.00%
#
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3285...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3289...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3293...
# ✅ Final score for asitwas_jacket_2: 82.50%
#
# 🎨 Processing asitwas_run (Frame 1) at frame 3302...
# 🎨 Processing asitwas_run (Frame 2) at frame 3306...
# 🎨 Processing asitwas_run (Frame 3) at frame 3311...
# ✅ Final score for asitwas_run: 67.50%
#
# 🎨 Processing asitwas_hair (Frame 1) at frame 3319...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3324...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3328...
# ✅ Final score for asitwas_hair: 75.00%
#
# 🎨 Processing asitwas_run (Frame 1) at frame 3337...
# 🎨 Processing asitwas_run (Frame 2) at frame 3341...
# 🎨 Processing asitwas_run (Frame 3) at frame 3345...
# ✅ Final score for asitwas_run: 60.00%
#
# 🎨 Processing asitwas_hair (Frame 1) at frame 3354...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3358...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3362...
# ✅ Final score for asitwas_hair: 62.50%
#
# 🎨 Processing asitwas_jacket_2_start (Frame 1) at frame 3371...
# 🎨 Processing asitwas_jacket_2_start (Frame 2) at frame 3375...
# 🎨 Processing asitwas_jacket_2_start (Frame 3) at frame 3380...
# ✅ Final score for asitwas_jacket_2_start: 80.00%
#
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3388...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3393...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3397...
# ✅ Final score for asitwas_jacket_2: 70.00%
#
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3405...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3410...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3414...
# ✅ Final score for asitwas_jacket_2: 80.00%
#
# 🎨 Processing asitwas_jacket_end (Frame 1) at frame 3423...
# 🎨 Processing asitwas_jacket_end (Frame 2) at frame 3427...
# 🎨 Processing asitwas_jacket_end (Frame 3) at frame 3431...
# ✅ Final score for asitwas_jacket_end: 80.00%
#
# 🎨 Processing asitwas_hands (Frame 1) at frame 3440...
# 🎨 Processing asitwas_hands (Frame 2) at frame 3444...
# 🎨 Processing asitwas_hands (Frame 3) at frame 3449...
# ✅ Final score for asitwas_hands: 92.50%
#
# 🎨 Processing asitwas_hands_2 (Frame 1) at frame 3457...
# 🎨 Processing asitwas_hands_2 (Frame 2) at frame 3462...
# 🎨 Processing asitwas_hands_2 (Frame 3) at frame 3466...
# ✅ Final score for asitwas_hands_2: 80.00%
#
# 🎨 Processing asitwas_head_down (Frame 1) at frame 3483...
# 🎨 Processing asitwas_head_down (Frame 2) at frame 3487...
# 🎨 Processing asitwas_head_down (Frame 3) at frame 3492...
# ✅ Final score for asitwas_head_down: 77.50%
#
# 🎨 Processing asitwas_jump (Frame 1) at frame 3500...
# 🎨 Processing asitwas_jump (Frame 2) at frame 3505...
# 🎨 Processing asitwas_jump (Frame 3) at frame 3509...
# ✅ Final score for asitwas_jump: 75.00%
#
# 🎨 Processing asitwas_knee (Frame 1) at frame 3561...
# 🎨 Processing asitwas_knee (Frame 2) at frame 3565...
# 🎨 Processing asitwas_knee (Frame 3) at frame 3569...
# ✅ Final score for asitwas_knee: 85.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3578...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3582...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3587...
# ✅ Final score for asitwas_hi: 72.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3612...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3617...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3621...
# ✅ Final score for asitwas_hi: 75.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3647...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3651...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3656...
# ✅ Final score for asitwas_drum: 92.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3664...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3668...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3673...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3681...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3686...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3690...
# ✅ Final score for asitwas_drum: 87.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3699...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3703...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3707...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3716...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3720...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3725...
# ✅ Final score for asitwas_hi: 85.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3750...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3755...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3759...
# ✅ Final score for asitwas_hi: 72.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3785...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3789...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3793...
# ✅ Final score for asitwas_drum: 82.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3802...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3806...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3811...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3819...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3824...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3828...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3837...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3841...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3845...
# ✅ Final score for asitwas_drum: 82.50%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3854...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3858...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3862...
# ✅ Final score for asitwas_hi: 80.00%
#
# 🎨 Processing asitwas_hi (Frame 1) at frame 3888...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3893...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3897...
# ✅ Final score for asitwas_hi: 75.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3923...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3927...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3931...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3940...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3944...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3949...
# ✅ Final score for asitwas_drum: 85.00%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3957...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3962...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3966...
# ✅ Final score for asitwas_drum: 92.50%
#
# 🎨 Processing asitwas_drum (Frame 1) at frame 3974...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3979...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3983...
# ✅ Final score for asitwas_drum: 80.00%
#
# 🎨 Processing asitwas_arms_open (Frame 1) at frame 3992...
# 🎨 Processing asitwas_arms_open (Frame 2) at frame 3996...
# 🎨 Processing asitwas_arms_open (Frame 3) at frame 4000...
# ✅ Final score for asitwas_arms_open: 75.00%
#
# 🎨 Processing asitwas_arms_close (Frame 1) at frame 4030...
# 🎨 Processing asitwas_arms_close (Frame 2) at frame 4035...
# 🎨 Processing asitwas_arms_close (Frame 3) at frame 4039...
# ✅ Final score for asitwas_arms_close: 72.50%
#
# 🎨 Processing asitwas_final_pose (Frame 1) at frame 4048...
# 🎨 Processing asitwas_final_pose (Frame 2) at frame 4052...
# 🎨 Processing asitwas_final_pose (Frame 3) at frame 4056...
# ✅ Final score for asitwas_final_pose: 75.00%
#
#
# ✅ Final Accuracy: 78.70%

# %%
## Score 3 Frames with drawing ref ##

import cv2
import mediapipe as mp
import json
import numpy as np
import joblib

# Load timeline.json
with open("timeline.json", "r") as f:
    timeline_data = json.load(f)

moves = timeline_data["moves"]  # Extract move data

# Load reference move data
reference_data = joblib.load("reference_moves_three/reference_data.pkl")

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose()

# Load the dance video
video_path = "videoplayback_25fps.mp4"  # Change this to your video file
cap = cv2.VideoCapture(video_path)

# Check if video loaded successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)  # Frames per second
print(f"Video FPS: {fps}")

# Define Colors
BLUE = (255, 0, 0)  # Reference Pose Color
RED = (0, 0, 255)   # Detected Pose Color

# Joint Connections
connections = [
    ("left_shoulder", "left_elbow"), ("left_elbow", "left_wrist"),
    ("right_shoulder", "right_elbow"), ("right_elbow", "right_wrist"),
    ("left_shoulder", "left_hip"), ("right_shoulder", "right_hip"),
]

def calculate_angle(a, b, c):
    """Calculate angle between three 3D points using the arctangent function."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))

    return np.degrees(angle)

def process_frame(image):
    """Extract pose landmarks from a frame and compute only left elbow and left arm lift angles."""
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Extract key joint coordinates (normalized values)
        joint_ids = {
            "left_shoulder": 11,
            "left_elbow": 13,
            "left_wrist": 15,
            "left_hip": 23
        }

        joints = {name: (landmarks[idx].x, landmarks[idx].y, landmarks[idx].z) for name, idx in joint_ids.items()}

        # Compute angles
        angles = {}

        if all(k in joints for k in ["left_shoulder", "left_elbow", "left_wrist"]):
            angles["left_elbow"] = calculate_angle(joints["left_shoulder"], joints["left_elbow"], joints["left_wrist"])
        if all(k in joints for k in ["left_elbow", "left_shoulder", "left_hip"]):
            angles["left_arm_lift"] = calculate_angle(joints["left_elbow"], joints["left_shoulder"], joints["left_hip"])

        return {"joints": joints, "angles": angles}

    return None



def draw_landmarks(frame, joints, color):
    """Draws landmarks and connections on the frame."""
    height, width, _ = frame.shape

    # Convert normalized joint coordinates to pixel values
    joint_positions = {key: (int(x * width), int(y * height)) for key, (x, y, z) in joints.items()}

    # Draw connections
    for joint1, joint2 in connections:
        if joint1 in joint_positions and joint2 in joint_positions:
            cv2.line(frame, joint_positions[joint1], joint_positions[joint2], color, 2)

    # Draw joints
    for joint, (x, y) in joint_positions.items():
        cv2.circle(frame, (x, y), 5, color, -1)

def score_angles(reference_angles, detected_angles):
    """Compare angles with reference and return a score."""
    total_score = 0
    count = 0

    for key in reference_angles:
        if key in detected_angles:
            diff = abs(reference_angles[key] - detected_angles[key])

            if diff < 20:
                score = 100  # Perfect
            elif diff < 40:
                score = 70  # Okay
            else:
                score = 40  # Bad

            total_score += score
            count += 1

    return total_score / count if count > 0 else 0  # Average score

# Initialize final accuracy tracking
total_moves = 0
total_accuracy = 0

# Process each move in the timeline
for move in moves:
    move_name = move["name"]
    start_time = move["time"] + 2.1  # Adjust timing offset
    duration = move["duration"]

    # Get the three frame times (25%, 50%, and 75% of move duration)
    frame_times = [
        start_time + (duration * 0.25),
        start_time + (duration * 0.5),
        start_time + (duration * 0.75)
    ]
    frame_indices = [int(t * fps) for t in frame_times]  # Convert times to frame indices

    if move_name not in reference_data or len(reference_data[move_name]) < 3:
        print(f"❌ No reference data found for {move_name}, skipping...")
        continue

    total_move_score = 0  
    valid_frames = 0  

    for i, frame_idx in enumerate(frame_indices):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  
        ret, frame = cap.read()

        if not ret:
            print(f"❌ Failed to capture frame {i+1} for {move_name} at frame {frame_idx}!")
            continue

        print(f"🎨 Processing {move_name} (Frame {i+1}) at frame {frame_idx}...")

        detected_pose = process_frame(frame)
        if not detected_pose:
            print(f"❌ No pose detected for {move_name} (Frame {i+1})")
            continue

        reference_joints = reference_data[move_name][i]["joints"]
        reference_angles = reference_data[move_name][i]["angles"]

        score = score_angles(reference_angles, detected_pose["angles"])
        total_move_score += score
        valid_frames += 1

        draw_landmarks(frame, reference_joints, BLUE)  # Draw reference pose (blue)
        draw_landmarks(frame, detected_pose["joints"], RED)  # Draw detected pose (red)

        cv2.putText(frame, f"Move: {move_name}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
        cv2.putText(frame, f"Score: {int(score)}", (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        cv2.imshow("Dance Scoring", frame)
        if cv2.waitKey(100) == ord('q'):
            break

    if valid_frames > 0:
        total_moves += 1
        total_accuracy += total_move_score / valid_frames

print(f"\n✅ Final Accuracy: {total_accuracy / total_moves:.2f}%") if total_moves else print("\n❌ No valid moves detected.")
cv2.destroyAllWindows()
cap.release()
# Out:
# Video FPS: 25.0
# 🎨 Processing asitwas_jacket (Frame 1) at frame 173...
# 🎨 Processing asitwas_jacket (Frame 2) at frame 177...
# 🎨 Processing asitwas_jacket (Frame 3) at frame 181...
# 🎨 Processing asitwas_snap (Frame 1) at frame 190...
# 🎨 Processing asitwas_snap (Frame 2) at frame 194...
# 🎨 Processing asitwas_snap (Frame 3) at frame 199...
# 🎨 Processing asitwas_arm_up (Frame 1) at frame 208...
# 🎨 Processing asitwas_arm_up (Frame 2) at frame 214...
# 🎨 Processing asitwas_arm_up (Frame 3) at frame 219...
# 🎨 Processing asitwas_snap_down_start (Frame 1) at frame 268...
# 🎨 Processing asitwas_snap_down_start (Frame 2) at frame 272...
# 🎨 Processing asitwas_snap_down_start (Frame 3) at frame 276...
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 285...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 289...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 293...
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 302...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 306...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 311...
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 319...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 324...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 328...
# 🎨 Processing asitwas_snap_down_start_2 (Frame 1) at frame 337...
# 🎨 Processing asitwas_snap_down_start_2 (Frame 2) at frame 341...
# 🎨 Processing asitwas_snap_down_start_2 (Frame 3) at frame 345...
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 354...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 358...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 362...
# 🎨 Processing asitwas_snap_down (Frame 1) at frame 371...
# 🎨 Processing asitwas_snap_down (Frame 2) at frame 375...
# 🎨 Processing asitwas_snap_down (Frame 3) at frame 380...
# 🎨 Processing asitwas_snap_down_end (Frame 1) at frame 388...
# 🎨 Processing asitwas_snap_down_end (Frame 2) at frame 393...
# 🎨 Processing asitwas_snap_down_end (Frame 3) at frame 397...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 405...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 410...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 414...
# 🎨 Processing asitwas_sun (Frame 1) at frame 423...
# 🎨 Processing asitwas_sun (Frame 2) at frame 427...
# 🎨 Processing asitwas_sun (Frame 3) at frame 431...
# 🎨 Processing asitwas_fists (Frame 1) at frame 440...
# 🎨 Processing asitwas_fists (Frame 2) at frame 444...
# 🎨 Processing asitwas_fists (Frame 3) at frame 449...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 474...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 479...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 483...
# 🎨 Processing asitwas_sun (Frame 1) at frame 492...
# 🎨 Processing asitwas_sun (Frame 2) at frame 496...
# 🎨 Processing asitwas_sun (Frame 3) at frame 500...
# 🎨 Processing asitwas_fists (Frame 1) at frame 509...
# 🎨 Processing asitwas_fists (Frame 2) at frame 513...
# 🎨 Processing asitwas_fists (Frame 3) at frame 518...
# 🎨 Processing asitwas_circle (Frame 1) at frame 543...
# 🎨 Processing asitwas_circle (Frame 2) at frame 548...
# 🎨 Processing asitwas_circle (Frame 3) at frame 552...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 578...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 582...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 587...
# 🎨 Processing asitwas_circle (Frame 1) at frame 612...
# 🎨 Processing asitwas_circle (Frame 2) at frame 617...
# 🎨 Processing asitwas_circle (Frame 3) at frame 621...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 647...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 651...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 656...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 681...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 686...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 690...
# 🎨 Processing asitwas_sun (Frame 1) at frame 699...
# 🎨 Processing asitwas_sun (Frame 2) at frame 703...
# 🎨 Processing asitwas_sun (Frame 3) at frame 707...
# 🎨 Processing asitwas_fists (Frame 1) at frame 716...
# 🎨 Processing asitwas_fists (Frame 2) at frame 720...
# 🎨 Processing asitwas_fists (Frame 3) at frame 725...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 750...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 755...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 759...
# 🎨 Processing asitwas_sun (Frame 1) at frame 768...
# 🎨 Processing asitwas_sun (Frame 2) at frame 772...
# 🎨 Processing asitwas_sun (Frame 3) at frame 776...
# 🎨 Processing asitwas_fists (Frame 1) at frame 785...
# 🎨 Processing asitwas_fists (Frame 2) at frame 789...
# 🎨 Processing asitwas_fists (Frame 3) at frame 793...
# 🎨 Processing asitwas_circle (Frame 1) at frame 819...
# 🎨 Processing asitwas_circle (Frame 2) at frame 824...
# 🎨 Processing asitwas_circle (Frame 3) at frame 828...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 854...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 858...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 862...
# 🎨 Processing asitwas_circle (Frame 1) at frame 888...
# 🎨 Processing asitwas_circle (Frame 2) at frame 893...
# 🎨 Processing asitwas_circle (Frame 3) at frame 897...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 923...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 927...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 931...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 957...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 962...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 966...
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 974...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 979...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 983...
# 🎨 Processing asitwas_belly (Frame 1) at frame 991...
# 🎨 Processing asitwas_belly (Frame 2) at frame 994...
# 🎨 Processing asitwas_belly (Frame 3) at frame 997...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1004...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1007...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1010...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1018...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1022...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1026...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1035...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1039...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1043...
# 🎨 Processing asitwas_belly (Frame 1) at frame 1060...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1063...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1066...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1073...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1076...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1079...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1087...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1091...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1095...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1104...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1108...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1112...
# 🎨 Processing asitwas_belly (Frame 1) at frame 1129...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1132...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1135...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1141...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1145...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1148...
# 🎨 Processing asitwas_hips (Frame 1) at frame 1155...
# 🎨 Processing asitwas_hips (Frame 2) at frame 1160...
# 🎨 Processing asitwas_hips (Frame 3) at frame 1164...
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 1173...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 1177...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 1181...
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 1194...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 1199...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 1203...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 1212...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 1216...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 1220...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1233...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1237...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1242...
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 1250...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 1255...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 1259...
# 🎨 Processing asitwas_belly (Frame 1) at frame 1266...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1270...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1273...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1279...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1283...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1286...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1293...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1298...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1302...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1311...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1315...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1319...
# 🎨 Processing asitwas_belly (Frame 1) at frame 1335...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1339...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1342...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1348...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1352...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1355...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 1362...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 1367...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 1371...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 1380...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 1384...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 1388...
# 🎨 Processing asitwas_belly (Frame 1) at frame 1404...
# 🎨 Processing asitwas_belly (Frame 2) at frame 1408...
# 🎨 Processing asitwas_belly (Frame 3) at frame 1411...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 1417...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 1421...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 1424...
# 🎨 Processing asitwas_hips (Frame 1) at frame 1431...
# 🎨 Processing asitwas_hips (Frame 2) at frame 1436...
# 🎨 Processing asitwas_hips (Frame 3) at frame 1440...
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 1449...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 1453...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 1457...
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 1470...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 1474...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 1479...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 1487...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 1492...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 1496...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1509...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1513...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1518...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1526...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1531...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1535...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1543...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1548...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1552...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1561...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1565...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1569...
# 🎨 Processing asitwas_hi (Frame 1) at frame 1578...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1582...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1587...
# 🎨 Processing asitwas_hi (Frame 1) at frame 1612...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1617...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1621...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1647...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1651...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1656...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1664...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1668...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1673...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1681...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1686...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1690...
# 🎨 Processing asitwas_drum (Frame 1) at frame 1699...
# 🎨 Processing asitwas_drum (Frame 2) at frame 1703...
# 🎨 Processing asitwas_drum (Frame 3) at frame 1707...
# 🎨 Processing asitwas_hi (Frame 1) at frame 1716...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1720...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1725...
# 🎨 Processing asitwas_hi (Frame 1) at frame 1750...
# 🎨 Processing asitwas_hi (Frame 2) at frame 1755...
# 🎨 Processing asitwas_hi (Frame 3) at frame 1759...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 1785...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 1789...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 1793...
# 🎨 Processing asitwas_sun (Frame 1) at frame 1802...
# 🎨 Processing asitwas_sun (Frame 2) at frame 1806...
# 🎨 Processing asitwas_sun (Frame 3) at frame 1811...
# 🎨 Processing asitwas_fists (Frame 1) at frame 1819...
# 🎨 Processing asitwas_fists (Frame 2) at frame 1824...
# 🎨 Processing asitwas_fists (Frame 3) at frame 1828...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 1854...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 1858...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 1862...
# 🎨 Processing asitwas_sun (Frame 1) at frame 1871...
# 🎨 Processing asitwas_sun (Frame 2) at frame 1875...
# 🎨 Processing asitwas_sun (Frame 3) at frame 1880...
# 🎨 Processing asitwas_fists (Frame 1) at frame 1888...
# 🎨 Processing asitwas_fists (Frame 2) at frame 1893...
# 🎨 Processing asitwas_fists (Frame 3) at frame 1897...
# 🎨 Processing asitwas_circle (Frame 1) at frame 1923...
# 🎨 Processing asitwas_circle (Frame 2) at frame 1927...
# 🎨 Processing asitwas_circle (Frame 3) at frame 1931...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 1957...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 1962...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 1966...
# 🎨 Processing asitwas_circle (Frame 1) at frame 1992...
# 🎨 Processing asitwas_circle (Frame 2) at frame 1996...
# 🎨 Processing asitwas_circle (Frame 3) at frame 2000...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 2026...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 2031...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 2035...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 2061...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 2065...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 2069...
# 🎨 Processing asitwas_sun (Frame 1) at frame 2078...
# 🎨 Processing asitwas_sun (Frame 2) at frame 2082...
# 🎨 Processing asitwas_sun (Frame 3) at frame 2087...
# 🎨 Processing asitwas_fists (Frame 1) at frame 2095...
# 🎨 Processing asitwas_fists (Frame 2) at frame 2099...
# 🎨 Processing asitwas_fists (Frame 3) at frame 2104...
# 🎨 Processing asitwas_arm_down (Frame 1) at frame 2130...
# 🎨 Processing asitwas_arm_down (Frame 2) at frame 2134...
# 🎨 Processing asitwas_arm_down (Frame 3) at frame 2138...
# 🎨 Processing asitwas_sun (Frame 1) at frame 2147...
# 🎨 Processing asitwas_sun (Frame 2) at frame 2151...
# 🎨 Processing asitwas_sun (Frame 3) at frame 2156...
# 🎨 Processing asitwas_fists (Frame 1) at frame 2164...
# 🎨 Processing asitwas_fists (Frame 2) at frame 2168...
# 🎨 Processing asitwas_fists (Frame 3) at frame 2173...
# 🎨 Processing asitwas_circle (Frame 1) at frame 2199...
# 🎨 Processing asitwas_circle (Frame 2) at frame 2203...
# 🎨 Processing asitwas_circle (Frame 3) at frame 2207...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 2233...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 2237...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 2242...
# 🎨 Processing asitwas_circle (Frame 1) at frame 2268...
# 🎨 Processing asitwas_circle (Frame 2) at frame 2272...
# 🎨 Processing asitwas_circle (Frame 3) at frame 2276...
# 🎨 Processing asitwas_circle_2 (Frame 1) at frame 2302...
# 🎨 Processing asitwas_circle_2 (Frame 2) at frame 2306...
# 🎨 Processing asitwas_circle_2 (Frame 3) at frame 2311...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2337...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2341...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2345...
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 2354...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 2358...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 2362...
# 🎨 Processing asitwas_belly (Frame 1) at frame 2370...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2373...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2376...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2383...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2386...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2389...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2397...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2401...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2406...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2414...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2418...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2423...
# 🎨 Processing asitwas_belly (Frame 1) at frame 2439...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2442...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2445...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2452...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2455...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2458...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2466...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2470...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2475...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2483...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2487...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2492...
# 🎨 Processing asitwas_belly (Frame 1) at frame 2508...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2511...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2514...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2521...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2524...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2527...
# 🎨 Processing asitwas_hips (Frame 1) at frame 2535...
# 🎨 Processing asitwas_hips (Frame 2) at frame 2539...
# 🎨 Processing asitwas_hips (Frame 3) at frame 2543...
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 2552...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 2556...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 2561...
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 2574...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 2578...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 2582...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 2591...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 2595...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 2600...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2612...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2617...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2621...
# 🎨 Processing asitwas_arm_fall (Frame 1) at frame 2630...
# 🎨 Processing asitwas_arm_fall (Frame 2) at frame 2634...
# 🎨 Processing asitwas_arm_fall (Frame 3) at frame 2638...
# 🎨 Processing asitwas_belly (Frame 1) at frame 2646...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2649...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2652...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2659...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2662...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2665...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2673...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2677...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2681...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2690...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2694...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2699...
# 🎨 Processing asitwas_belly (Frame 1) at frame 2715...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2718...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2721...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2728...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2731...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2734...
# 🎨 Processing asitwas_cross_arm (Frame 1) at frame 2742...
# 🎨 Processing asitwas_cross_arm (Frame 2) at frame 2746...
# 🎨 Processing asitwas_cross_arm (Frame 3) at frame 2750...
# 🎨 Processing asitwas_arm_fall_2 (Frame 1) at frame 2759...
# 🎨 Processing asitwas_arm_fall_2 (Frame 2) at frame 2763...
# 🎨 Processing asitwas_arm_fall_2 (Frame 3) at frame 2768...
# 🎨 Processing asitwas_belly (Frame 1) at frame 2784...
# 🎨 Processing asitwas_belly (Frame 2) at frame 2787...
# 🎨 Processing asitwas_belly (Frame 3) at frame 2790...
# 🎨 Processing asitwas_belly_2 (Frame 1) at frame 2797...
# 🎨 Processing asitwas_belly_2 (Frame 2) at frame 2800...
# 🎨 Processing asitwas_belly_2 (Frame 3) at frame 2803...
# 🎨 Processing asitwas_hips (Frame 1) at frame 2811...
# 🎨 Processing asitwas_hips (Frame 2) at frame 2815...
# 🎨 Processing asitwas_hips (Frame 3) at frame 2819...
# 🎨 Processing asitwas_hips_2 (Frame 1) at frame 2828...
# 🎨 Processing asitwas_hips_2 (Frame 2) at frame 2832...
# 🎨 Processing asitwas_hips_2 (Frame 3) at frame 2837...
# 🎨 Processing asitwas_snap_chorus (Frame 1) at frame 2849...
# 🎨 Processing asitwas_snap_chorus (Frame 2) at frame 2854...
# 🎨 Processing asitwas_snap_chorus (Frame 3) at frame 2858...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 1) at frame 2867...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 2) at frame 2871...
# 🎨 Processing asitwas_snap_chorus_2 (Frame 3) at frame 2875...
# 🎨 Processing asitwas_drum (Frame 1) at frame 2888...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2893...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2897...
# 🎨 Processing asitwas_drum (Frame 1) at frame 2905...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2910...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2914...
# 🎨 Processing asitwas_drum (Frame 1) at frame 2923...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2927...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2931...
# 🎨 Processing asitwas_drum (Frame 1) at frame 2940...
# 🎨 Processing asitwas_drum (Frame 2) at frame 2944...
# 🎨 Processing asitwas_drum (Frame 3) at frame 2949...
# 🎨 Processing asitwas_hi (Frame 1) at frame 2957...
# 🎨 Processing asitwas_hi (Frame 2) at frame 2962...
# 🎨 Processing asitwas_hi (Frame 3) at frame 2966...
# 🎨 Processing asitwas_hi (Frame 1) at frame 2992...
# 🎨 Processing asitwas_hi (Frame 2) at frame 2996...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3000...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3026...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3031...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3035...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3043...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3048...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3052...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3061...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3065...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3069...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3078...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3082...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3087...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3095...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3099...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3104...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3130...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3134...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3138...
# 🎨 Processing asitwas_run (Frame 1) at frame 3164...
# 🎨 Processing asitwas_run (Frame 2) at frame 3168...
# 🎨 Processing asitwas_run (Frame 3) at frame 3173...
# 🎨 Processing asitwas_hair (Frame 1) at frame 3181...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3186...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3190...
# 🎨 Processing asitwas_run (Frame 1) at frame 3199...
# 🎨 Processing asitwas_run (Frame 2) at frame 3203...
# 🎨 Processing asitwas_run (Frame 3) at frame 3207...
# 🎨 Processing asitwas_hair (Frame 1) at frame 3216...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3220...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3225...
# 🎨 Processing asitwas_jacket_2_start (Frame 1) at frame 3233...
# 🎨 Processing asitwas_jacket_2_start (Frame 2) at frame 3237...
# 🎨 Processing asitwas_jacket_2_start (Frame 3) at frame 3242...
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3250...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3255...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3259...
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3268...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3272...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3276...
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3285...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3289...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3293...
# 🎨 Processing asitwas_run (Frame 1) at frame 3302...
# 🎨 Processing asitwas_run (Frame 2) at frame 3306...
# 🎨 Processing asitwas_run (Frame 3) at frame 3311...
# 🎨 Processing asitwas_hair (Frame 1) at frame 3319...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3324...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3328...
# 🎨 Processing asitwas_run (Frame 1) at frame 3337...
# 🎨 Processing asitwas_run (Frame 2) at frame 3341...
# 🎨 Processing asitwas_run (Frame 3) at frame 3345...
# 🎨 Processing asitwas_hair (Frame 1) at frame 3354...
# 🎨 Processing asitwas_hair (Frame 2) at frame 3358...
# 🎨 Processing asitwas_hair (Frame 3) at frame 3362...
# 🎨 Processing asitwas_jacket_2_start (Frame 1) at frame 3371...
# 🎨 Processing asitwas_jacket_2_start (Frame 2) at frame 3375...
# 🎨 Processing asitwas_jacket_2_start (Frame 3) at frame 3380...
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3388...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3393...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3397...
# 🎨 Processing asitwas_jacket_2 (Frame 1) at frame 3405...
# 🎨 Processing asitwas_jacket_2 (Frame 2) at frame 3410...
# 🎨 Processing asitwas_jacket_2 (Frame 3) at frame 3414...
# 🎨 Processing asitwas_jacket_end (Frame 1) at frame 3423...
# 🎨 Processing asitwas_jacket_end (Frame 2) at frame 3427...
# 🎨 Processing asitwas_jacket_end (Frame 3) at frame 3431...
# 🎨 Processing asitwas_hands (Frame 1) at frame 3440...
# 🎨 Processing asitwas_hands (Frame 2) at frame 3444...
# 🎨 Processing asitwas_hands (Frame 3) at frame 3449...
# 🎨 Processing asitwas_hands_2 (Frame 1) at frame 3457...
# 🎨 Processing asitwas_hands_2 (Frame 2) at frame 3462...
# 🎨 Processing asitwas_hands_2 (Frame 3) at frame 3466...
# 🎨 Processing asitwas_head_down (Frame 1) at frame 3483...
# 🎨 Processing asitwas_head_down (Frame 2) at frame 3487...
# 🎨 Processing asitwas_head_down (Frame 3) at frame 3492...
# 🎨 Processing asitwas_jump (Frame 1) at frame 3500...
# 🎨 Processing asitwas_jump (Frame 2) at frame 3505...
# 🎨 Processing asitwas_jump (Frame 3) at frame 3509...
# 🎨 Processing asitwas_knee (Frame 1) at frame 3561...
# 🎨 Processing asitwas_knee (Frame 2) at frame 3565...
# 🎨 Processing asitwas_knee (Frame 3) at frame 3569...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3578...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3582...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3587...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3612...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3617...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3621...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3647...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3651...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3656...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3664...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3668...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3673...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3681...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3686...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3690...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3699...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3703...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3707...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3716...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3720...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3725...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3750...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3755...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3759...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3785...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3789...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3793...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3802...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3806...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3811...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3819...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3824...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3828...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3837...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3841...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3845...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3854...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3858...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3862...
# 🎨 Processing asitwas_hi (Frame 1) at frame 3888...
# 🎨 Processing asitwas_hi (Frame 2) at frame 3893...
# 🎨 Processing asitwas_hi (Frame 3) at frame 3897...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3923...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3927...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3931...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3940...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3944...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3949...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3957...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3962...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3966...
# 🎨 Processing asitwas_drum (Frame 1) at frame 3974...
# 🎨 Processing asitwas_drum (Frame 2) at frame 3979...
# 🎨 Processing asitwas_drum (Frame 3) at frame 3983...
# 🎨 Processing asitwas_arms_open (Frame 1) at frame 3992...
# 🎨 Processing asitwas_arms_open (Frame 2) at frame 3996...
# 🎨 Processing asitwas_arms_open (Frame 3) at frame 4000...
# 🎨 Processing asitwas_arms_close (Frame 1) at frame 4030...
# 🎨 Processing asitwas_arms_close (Frame 2) at frame 4035...
# 🎨 Processing asitwas_arms_close (Frame 3) at frame 4039...
# 🎨 Processing asitwas_final_pose (Frame 1) at frame 4048...
# 🎨 Processing asitwas_final_pose (Frame 2) at frame 4052...
# 🎨 Processing asitwas_final_pose (Frame 3) at frame 4056...
#
# ✅ Final Accuracy: 80.25%

# %%
7 - 4.65517139
# Out:
# 2.3448286100000004
